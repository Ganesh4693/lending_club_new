# %%
from numpy.random import randint as rint

# %%
olist=rint(0,100,100)

# %%
olist
# Out:
# array([28, 97, 64, 66, 36, 87, 38, 77, 32, 55, 32, 58, 67, 49, 23,  8, 50,
#        81, 81, 45, 57, 92, 91, 16, 74, 19, 64, 95, 17, 94, 64, 58, 19, 87,
#        66, 17, 72, 56, 74, 72, 95, 61, 73, 55, 59, 24, 87, 20, 36, 42, 15,
#        20, 37, 36, 71, 94, 48, 19, 19, 55, 32, 48, 86, 21, 36, 36, 93,  9,
#        37,  5, 84, 60, 26, 29, 97, 63, 47, 55, 85, 56, 79, 50, 46, 85, 36,
#        50, 71, 44, 82, 16, 39, 91, 33, 57, 77,  3, 10, 27, 32, 63])
