# %%
import numpy as np
import pandas as pd

# %%
def fnct(num1, num2):
    i=0
    for num1 in range(num2,num2+10):
        num1+=5
        i+=1
    return i

# %%
fnct(1,100)
# Out:
# 10

# %%
list(range(100,110,5))
# Out:
# [100, 105]

# %%
a=2
b=3

# %%
a,b
# Out:
# (2, 3)

# %%
a,b=b,a

# %%
a,b
# Out:
# (3, 2)

# %%
a=[4,2,3,6,1,6,5]
b=set(a)
b=list(b)
c=sorted(b)
c[-2]
# Out:
# 5
