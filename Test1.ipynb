# %%
def selector(list1, target):
    newlist=[]
    length=len(list1)
    for a in range(length):
        for b in range(length):
            if a!=b:
                if (list1[a]+list1[b])==target:
                    newlist.append(list[a])
                    newlist.append(list[b])
                    return newlist
            
    return newlist

# %%
def selector2(list1,target):
    new=[]
    for a in range(len(list1)):
        if (target-list1[a]) in list1:
            new.append(list1[a])
            new.append(target-list1[a])
            return new
    return new
