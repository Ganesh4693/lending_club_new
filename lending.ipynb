# %% [markdown]
# # Introduction
# LendingClub is a US peer-to-peer lending company, headquartered in San Francisco, California. It was the first peer-to-peer lender to register its offerings as securities with the Securities and Exchange Commission (SEC), and to offer loan trading on a secondary market. LendingClub is the world's largest peer-to-peer lending platform.

# %% [markdown]
# ### Our Goal
#
# Given historical data on loans given out with information on whether or not the borrower defaulted (charge-off), we can build a model that can predict wether or nor a borrower will pay back their loan
#
# The "loan_status" column contains our label.

# %% [markdown]
# ### Importing libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_theme(font_scale=1.5)
pd.set_option('display.max_colwidth',None)
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.callbacks import EarlyStopping,TensorBoard
from sklearn.metrics import classification_report, confusion_matrix
import random

# %% [markdown]
# ### Reading data

# %%
data0=pd.read_csv('lending_club_loan_two.csv')

# %%
data0.head()
# Out:
#    loan_amnt        term  int_rate  installment grade sub_grade  \
# 0    10000.0   36 months     11.44       329.48     B        B4
# 1     8000.0   36 months     11.99       265.68     B        B5
# 2    15600.0   36 months     10.49       506.97     B        B3
# 3     7200.0   36 months      6.49       220.65     A        A2
# 4    24375.0   60 months     17.27       609.33     C        C5
#
#                  emp_title emp_length home_ownership  annual_inc  ...  \
# 0                Marketing  10+ years           RENT    117000.0  ...
# 1          Credit analyst     4 years       MORTGAGE     65000.0  ...
# 2             Statistician   < 1 year           RENT     43057.0  ...
# 3          Client Advocate    6 years           RENT     54000.0  ...
# 4  Destiny Management Inc.    9 years       MORTGAGE     55000.0  ...
#
#   open_acc pub_rec revol_bal revol_util total_acc  initial_list_status  \
# 0     16.0     0.0   36369.0       41.8      25.0                    w
# 1     17.0     0.0   20131.0       53.3      27.0                    f
# 2     13.0     0.0   11987.0       92.2      26.0                    f
# 3      6.0     0.0    5472.0       21.5      13.0                    f
# 4     13.0     0.0   24584.0       69.8      43.0                    f
#
#   application_type  mort_acc  pub_rec_bankruptcies  \
# 0       INDIVIDUAL       0.0                   0.0
# 1       INDIVIDUAL       3.0                   0.0
# 2       INDIVIDUAL       0.0                   0.0
# 3       INDIVIDUAL       0.0                   0.0
# 4       INDIVIDUAL       1.0                   0.0
#
#                                            address
# 0     0174 Michelle Gateway\nMendozaberg, OK 22690
# 1  1076 Carney Fort Apt. 347\nLoganmouth, SD 05113
# 2  87025 Mark Dale Apt. 269\nNew Sabrina, WV 05113
# 3            823 Reid Ford\nDelacruzside, MA 00813
# 4             679 Luna Roads\nGreggshire, VA 11650
#
# [5 rows x 27 columns]

# %%
info=pd.read_csv("lending_club_info.csv")

# %%
info
# Out:
#              LoanStatNew  \
# 0              loan_amnt
# 1                   term
# 2               int_rate
# 3            installment
# 4                  grade
# 5              sub_grade
# 6              emp_title
# 7             emp_length
# 8         home_ownership
# 9             annual_inc
# 10   verification_status
# 11               issue_d
# 12           loan_status
# 13               purpose
# 14                 title
# 15              zip_code
# 16            addr_state
# 17                   dti
# 18      earliest_cr_line
# 19              open_acc
# 20               pub_rec
# 21             revol_bal
# 22            revol_util
# 23             total_acc
# 24   initial_list_status
# 25      application_type
# 26              mort_acc
# 27  pub_rec_bankruptcies
#
#                                                                                                                                                                                                  Description
# 0                               The listed amount of the loan applied for by the borrower. If at some point in time, the credit department reduces the loan amount, then it will be reflected in this value.
# 1                                                                                                                       The number of payments on the loan. Values are in months and can be either 36 or 60.
# 2                                                                                                                                                                                  Interest Rate on the loan
# 3                                                                                                                                           The monthly payment owed by the borrower if the loan originates.
# 4                                                                                                                                                                                     LC assigned loan grade
# 5                                                                                                                                                                                  LC assigned loan subgrade
# 6                                                                                                                                        The job title supplied by the Borrower when applying for the loan.*
# 7                                                                         Employment length in years. Possible values are between 0 and 10 where 0 means less than one year and 10 means ten or more years.
# 8                                                      The home ownership status provided by the borrower during registration or obtained from the credit report. Our values are: RENT, OWN, MORTGAGE, OTHER
# 9                                                                                                                              The self-reported annual income provided by the borrower during registration.
# 10                                                                                                                Indicates if income was verified by LC, not verified, or if the income source was verified
# 11                                                                                                                                                                       The month which the loan was funded
# 12                                                                                                                                                                                Current status of the loan
# 13                                                                                                                                                A category provided by the borrower for the loan request.
# 14                                                                                                                                                                   The loan title provided by the borrower
# 15                                                                                                                     The first 3 numbers of the zip code provided by the borrower in the loan application.
# 16                                                                                                                                                The state provided by the borrower in the loan application
# 17  A ratio calculated using the borrower’s total monthly debt payments on the total debt obligations, excluding mortgage and the requested LC loan, divided by the borrower’s self-reported monthly income.
# 18                                                                                                                                         The month the borrower's earliest reported credit line was opened
# 19                                                                                                                                            The number of open credit lines in the borrower's credit file.
# 20                                                                                                                                                                       Number of derogatory public records
# 21                                                                                                                                                                            Total credit revolving balance
# 22                                                                                Revolving line utilization rate, or the amount of credit the borrower is using relative to all available revolving credit.
# 23                                                                                                                                  The total number of credit lines currently in the borrower's credit file
# 24                                                                                                                                        The initial listing status of the loan. Possible values are – W, F
# 25                                                                                                      Indicates whether the loan is an individual application or a joint application with two co-borrowers
# 26                                                                                                                                                                              Number of mortgage accounts.
# 27                                                                                                                                                                      Number of public record bankruptcies

# %%
data0.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 396030 entries, 0 to 396029
# Data columns (total 27 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   loan_amnt             396030 non-null  float64
#  1   term                  396030 non-null  object
#  2   int_rate              396030 non-null  float64
#  3   installment           396030 non-null  float64
#  4   grade                 396030 non-null  object
#  5   sub_grade             396030 non-null  object
#  6   emp_title             373103 non-null  object
#  7   emp_length            377729 non-null  object
#  8   home_ownership        396030 non-null  object
#  9   annual_inc            396030 non-null  float64
#  10  verification_status   396030 non-null  object
#  11  issue_d               396030 non-null  object
#  12  loan_status           396030 non-null  object
#  13  purpose               396030 non-null  object
#  14  title                 394275 non-null  object
#  15  dti                   396030 non-null  float64
#  16  earliest_cr_line      396030 non-null  object
#  17  open_acc              396030 non-null  float64
#  18  pub_rec               396030 non-null  float64
#  19  revol_bal             396030 non-null  float64
#  20  revol_util            395754 non-null  float64
#  21  total_acc             396030 non-null  float64
#  22  initial_list_status   396030 non-null  object
#  23  application_type      396030 non-null  object
#  24  mort_acc              358235 non-null  float64
#  25  pub_rec_bankruptcies  395495 non-null  float64
#  26  address               396030 non-null  object
# dtypes: float64(12), object(15)
# memory usage: 81.6+ MB

# %% [markdown]
# # EDA

# %% [markdown]
# ## Target column

# %%
data1=data0.copy()

# %%
data1.loan_status.head()
# Out:
# 0     Fully Paid
# 1     Fully Paid
# 2     Fully Paid
# 3     Fully Paid
# 4    Charged Off
# Name: loan_status, dtype: object

# %% [markdown]
# ### Countplot of target column

# %%
plt.figure(figsize=(15,10))
sns.countplot(data=data1,x='loan_status')
# Out:
# <AxesSubplot:xlabel='loan_status', ylabel='count'>

# %% [markdown]
# **Unbalanced label distribution**

# %% [markdown]
# ### Encoding target column

# %%
data1.loan_status=pd.get_dummies(data1.loan_status,drop_first=True)

# %%
data1.loan_status.head()
# Out:
# 0    1
# 1    1
# 2    1
# 3    1
# 4    0
# Name: loan_status, dtype: uint8

# %% [markdown]
# ## Missing values

# %%
nulls=data1.isna().sum()
nulls
# Out:
# loan_amnt                   0
# term                        0
# int_rate                    0
# installment                 0
# grade                       0
# sub_grade                   0
# emp_title               22927
# emp_length              18301
# home_ownership              0
# annual_inc                  0
# verification_status         0
# issue_d                     0
# loan_status                 0
# purpose                     0
# title                    1755
# dti                         0
# earliest_cr_line            0
# open_acc                    0
# pub_rec                     0
# revol_bal                   0
# revol_util                276
# total_acc                   0
# initial_list_status         0
# application_type            0
# mort_acc                37795
# pub_rec_bankruptcies      535
# address                     0
# dtype: int64

# %% [markdown]
# ### Percentage missing

# %%
nulls[nulls.values!=0]/len(data1)*100
# Out:
# emp_title               5.789208
# emp_length              4.621115
# title                   0.443148
# revol_util              0.069692
# mort_acc                9.543469
# pub_rec_bankruptcies    0.135091
# dtype: float64

# %% [markdown]
# ## Correlations

# %%
data1.corr().loan_status.sort_values()[:-1]
# Out:
# int_rate               -0.247758
# revol_util             -0.082373
# dti                    -0.062413
# loan_amnt              -0.059836
# installment            -0.041082
# open_acc               -0.028012
# pub_rec                -0.019933
# pub_rec_bankruptcies   -0.009383
# revol_bal               0.010892
# total_acc               0.017893
# annual_inc              0.053432
# mort_acc                0.073111
# Name: loan_status, dtype: float64

# %%
plt.figure(figsize=(12,10))
data1.corr().loan_status.sort_values()[:-1].plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
correl=pd.DataFrame(data1.corr().loan_status.sort_values()[:-1]).reset_index()

# %%
correl
# Out:
#                    index  loan_status
# 0               int_rate    -0.247758
# 1             revol_util    -0.082373
# 2                    dti    -0.062413
# 3              loan_amnt    -0.059836
# 4            installment    -0.041082
# 5               open_acc    -0.028012
# 6                pub_rec    -0.019933
# 7   pub_rec_bankruptcies    -0.009383
# 8              revol_bal     0.010892
# 9              total_acc     0.017893
# 10            annual_inc     0.053432
# 11              mort_acc     0.073111

# %%
plt.figure(figsize=(12,10))
sns.barplot(y='index',x='loan_status',data=correl,palette='viridis')
# Out:
# <AxesSubplot:xlabel='loan_status', ylabel='index'>

# %% [markdown]
# **int_rate is the most negatively correlated with label at ~-0.25**

# %% [markdown]
# ### int_rate

# %%
info[info.LoanStatNew=='int_rate'].Description
# Out:
# 2    Interest Rate on the loan
# Name: Description, dtype: object

# %%
plt.figure(figsize=(12,10))
sns.histplot(data1.int_rate,bins=50)
# Out:
# <AxesSubplot:xlabel='int_rate', ylabel='Count'>

# %% [markdown]
# #### Bivariate plot

# %%
plt.figure(figsize=(12,10))
sns.histplot(data=data1,x='int_rate',bins=50,hue='loan_status',palette='hot_r')
# Out:
# <AxesSubplot:xlabel='int_rate', ylabel='Count'>

# %% [markdown]
# **More chance of Loan repayment when interest rates were lower**

# %% [markdown]
# ## Collinearity

# %%
plt.figure(figsize=(15,15))
sns.heatmap(data1.corr(),cmap='viridis',annot=True,annot_kws={'size':9})
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### installment and loan_amnt is highly correlated at 0.95

# %% [markdown]
# #### installment

# %%
info[info.LoanStatNew=='installment'].Description
# Out:
# 3    The monthly payment owed by the borrower if the loan originates.
# Name: Description, dtype: object

# %%
plt.figure(figsize=(12,10))
sns.histplot(data1.installment,bins=50)
# Out:
# <AxesSubplot:xlabel='installment', ylabel='Count'>

# %%
plt.figure(figsize=(12,10))
sns.histplot(data=data1,x='installment',bins=50,hue='loan_status',palette='hot_r')
# Out:
# <AxesSubplot:xlabel='installment', ylabel='Count'>

# %%
data1.installment.describe()
# Out:
# count    396030.000000
# mean        431.849698
# std         250.727790
# min          16.080000
# 25%         250.330000
# 50%         375.430000
# 75%         567.300000
# max        1533.810000
# Name: installment, dtype: float64

# %% [markdown]
# #### loan_amnt

# %%
info[info.LoanStatNew=='loan_amnt'].Description
# Out:
# 0    The listed amount of the loan applied for by the borrower. If at some point in time, the credit department reduces the loan amount, then it will be reflected in this value.
# Name: Description, dtype: object

# %%
plt.figure(figsize=(12,10))
sns.histplot(data1.loan_amnt,bins=50)
# Out:
# <AxesSubplot:xlabel='loan_amnt', ylabel='Count'>

# %%
plt.figure(figsize=(12,10))
sns.histplot(data=data1,x='loan_amnt',bins=50,hue='loan_status',palette='hot_r')
# Out:
# <AxesSubplot:xlabel='loan_amnt', ylabel='Count'>

# %%
data1.loan_amnt.describe()
# Out:
# count    396030.000000
# mean      14113.888089
# std        8357.441341
# min         500.000000
# 25%        8000.000000
# 50%       12000.000000
# 75%       20000.000000
# max       40000.000000
# Name: loan_amnt, dtype: float64

# %% [markdown]
# #### installment is directly correlated to the loan_amnt as it is usually a percentage of loan amount

# %%
plt.figure(figsize=(12,10))
sns.scatterplot(x='installment',y='loan_amnt',data=data1,palette='viridis')
# Out:
# <AxesSubplot:xlabel='installment', ylabel='loan_amnt'>

# %% [markdown]
# **Trivariate plot**

# %%
plt.figure(figsize=(12,10))
sns.scatterplot(x='installment',y='loan_amnt',data=data1,palette='hot_r',hue='loan_status')
# Out:
# <AxesSubplot:xlabel='installment', ylabel='loan_amnt'>

# %% [markdown]
# ### pub_rec and pub_rec_bankruptcies are correlated at 0.7

# %% [markdown]
# #### pub_rec

# %%
info[info.LoanStatNew=='pub_rec'].Description
# Out:
# 20    Number of derogatory public records
# Name: Description, dtype: object

# %%
data1.pub_rec.describe()
# Out:
# count    396030.000000
# mean          0.178191
# std           0.530671
# min           0.000000
# 25%           0.000000
# 50%           0.000000
# 75%           0.000000
# max          86.000000
# Name: pub_rec, dtype: float64

# %%
plt.figure(figsize=(12,10))
sns.histplot(data1.pub_rec,bins=50)
# Out:
# <AxesSubplot:xlabel='pub_rec', ylabel='Count'>

# %%
data1.pub_rec.value_counts()
# Out:
# 0.0     338272
# 1.0      49739
# 2.0       5476
# 3.0       1521
# 4.0        527
# 5.0        237
# 6.0        122
# 7.0         56
# 8.0         34
# 9.0         12
# 10.0        11
# 11.0         8
# 13.0         4
# 12.0         4
# 19.0         2
# 40.0         1
# 17.0         1
# 86.0         1
# 24.0         1
# 15.0         1
# Name: pub_rec, dtype: int64

# %%
data1[data1.pub_rec<7].pub_rec.value_counts()
# Out:
# 0.0    338272
# 1.0     49739
# 2.0      5476
# 3.0      1521
# 4.0       527
# 5.0       237
# 6.0       122
# Name: pub_rec, dtype: int64

# %%
len(data1[data1.pub_rec<4])/len(data1)*100
# Out:
# 99.7419387420145

# %% [markdown]
# **Histplot of pub_rec less than 4 (99.74% of data)**

# %%
plt.figure(figsize=(12,10))
sns.histplot(data1[data1.pub_rec<4].pub_rec,bins=10)
# Out:
# <AxesSubplot:xlabel='pub_rec', ylabel='Count'>

# %% [markdown]
# **Bivariate plot**

# %%
plt.figure(figsize=(12,10))
sns.histplot(data1[data1.pub_rec<4],x='pub_rec',hue='loan_status',palette='hot_r',bins=10,multiple='dodge')
# Out:
# <AxesSubplot:xlabel='pub_rec', ylabel='Count'>

# %% [markdown]
# #### pub_rec_bankruptcies

# %%
info[info.LoanStatNew=='pub_rec_bankruptcies'].Description
# Out:
# 27    Number of public record bankruptcies
# Name: Description, dtype: object

# %%
data1.pub_rec_bankruptcies.describe()
# Out:
# count    395495.000000
# mean          0.121648
# std           0.356174
# min           0.000000
# 25%           0.000000
# 50%           0.000000
# 75%           0.000000
# max           8.000000
# Name: pub_rec_bankruptcies, dtype: float64

# %%
data1.pub_rec_bankruptcies.value_counts()
# Out:
# 0.0    350380
# 1.0     42790
# 2.0      1847
# 3.0       351
# 4.0        82
# 5.0        32
# 6.0         7
# 7.0         4
# 8.0         2
# Name: pub_rec_bankruptcies, dtype: int64

# %%
plt.figure(figsize=(12,10))
sns.histplot(data1.pub_rec_bankruptcies,bins=50)
# Out:
# <AxesSubplot:xlabel='pub_rec_bankruptcies', ylabel='Count'>

# %% [markdown]
# **Bivariate plot**

# %%
plt.figure(figsize=(12,10))
sns.histplot(data1,x='pub_rec_bankruptcies',hue='loan_status',palette='hot_r',bins=10,multiple='dodge')
# Out:
# <AxesSubplot:xlabel='pub_rec_bankruptcies', ylabel='Count'>

# %% [markdown]
# #### Both features are indicative of past records of consumer. Hence correlated

# %%
plt.figure(figsize=(12,10))
sns.stripplot(x='pub_rec_bankruptcies',y='pub_rec',data=data1[data1.pub_rec<20],size=4)
# Out:
# <AxesSubplot:xlabel='pub_rec_bankruptcies', ylabel='pub_rec'>

# %% [markdown]
# **Trivariate plot**

# %%
plt.figure(figsize=(12,10))
sns.stripplot(x='pub_rec_bankruptcies',y='pub_rec',data=data1[data1.pub_rec<20],palette='hot_r',hue='loan_status')
# Out:
# <AxesSubplot:xlabel='pub_rec_bankruptcies', ylabel='pub_rec'>

# %% [markdown]
# ### open_acc and total_acc are correlated at 0.68

# %% [markdown]
# #### open_acc

# %%
info[info.LoanStatNew=='open_acc'].Description
# Out:
# 19    The number of open credit lines in the borrower's credit file.
# Name: Description, dtype: object

# %%
data1.open_acc.describe()
# Out:
# count    396030.000000
# mean         11.311153
# std           5.137649
# min           0.000000
# 25%           8.000000
# 50%          10.000000
# 75%          14.000000
# max          90.000000
# Name: open_acc, dtype: float64

# %%
plt.figure(figsize=(12,10))
sns.histplot(data1.open_acc,bins=50)
# Out:
# <AxesSubplot:xlabel='open_acc', ylabel='Count'>

# %%
plt.figure(figsize=(12,10))
sns.histplot(np.log1p(data1.open_acc),bins=100)
# Out:
# <AxesSubplot:xlabel='open_acc', ylabel='Count'>

# %% [markdown]
# **Bivariate plot of open_acc**

# %%
plt.figure(figsize=(12,10))
sns.histplot(data1,x='open_acc',bins=50,hue='loan_status',palette='hot_r')
# Out:
# <AxesSubplot:xlabel='open_acc', ylabel='Count'>

# %% [markdown]
# #### total_acc

# %%
info[info.LoanStatNew=='total_acc'].Description
# Out:
# 23    The total number of credit lines currently in the borrower's credit file
# Name: Description, dtype: object

# %%
data1.total_acc.describe()
# Out:
# count    396030.000000
# mean         25.414744
# std          11.886991
# min           2.000000
# 25%          17.000000
# 50%          24.000000
# 75%          32.000000
# max         151.000000
# Name: total_acc, dtype: float64

# %%
plt.figure(figsize=(12,10))
sns.histplot(data1.total_acc,bins=50)
# Out:
# <AxesSubplot:xlabel='total_acc', ylabel='Count'>

# %%
plt.figure(figsize=(12,10))
sns.histplot(np.log1p(data1.total_acc),bins=100)
# Out:
# <AxesSubplot:xlabel='total_acc', ylabel='Count'>

# %% [markdown]
# **Bivariate plot of total_acc**

# %%
plt.figure(figsize=(12,10))
sns.histplot(data1,x='total_acc',bins=50,hue='loan_status',palette='hot_r')
# Out:
# <AxesSubplot:xlabel='total_acc', ylabel='Count'>

# %% [markdown]
# #### One feature is a subset of another. Hence correlated

# %%
plt.figure(figsize=(12,10))
sns.scatterplot(x='open_acc',y='total_acc',data=data1,palette='viridis')
# Out:
# <AxesSubplot:xlabel='open_acc', ylabel='total_acc'>

# %% [markdown]
# **Trivariate plot**

# %%
plt.figure(figsize=(12,10))
sns.scatterplot(x='open_acc',y='total_acc',data=data1,palette='hot_r',hue='loan_status')
# Out:
# <AxesSubplot:xlabel='open_acc', ylabel='total_acc'>

# %% [markdown]
# ## Other numerical features

# %%
data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 396030 entries, 0 to 396029
# Data columns (total 27 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   loan_amnt             396030 non-null  float64
#  1   term                  396030 non-null  object
#  2   int_rate              396030 non-null  float64
#  3   installment           396030 non-null  float64
#  4   grade                 396030 non-null  object
#  5   sub_grade             396030 non-null  object
#  6   emp_title             373103 non-null  object
#  7   emp_length            377729 non-null  object
#  8   home_ownership        396030 non-null  object
#  9   annual_inc            396030 non-null  float64
#  10  verification_status   396030 non-null  object
#  11  issue_d               396030 non-null  object
#  12  loan_status           396030 non-null  uint8
#  13  purpose               396030 non-null  object
#  14  title                 394275 non-null  object
#  15  dti                   396030 non-null  float64
#  16  earliest_cr_line      396030 non-null  object
#  17  open_acc              396030 non-null  float64
#  18  pub_rec               396030 non-null  float64
#  19  revol_bal             396030 non-null  float64
#  20  revol_util            395754 non-null  float64
#  21  total_acc             396030 non-null  float64
#  22  initial_list_status   396030 non-null  object
#  23  application_type      396030 non-null  object
#  24  mort_acc              358235 non-null  float64
#  25  pub_rec_bankruptcies  395495 non-null  float64
#  26  address               396030 non-null  object
# dtypes: float64(12), object(14), uint8(1)
# memory usage: 78.9+ MB

# %%
data1.select_dtypes('float').info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 396030 entries, 0 to 396029
# Data columns (total 12 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   loan_amnt             396030 non-null  float64
#  1   int_rate              396030 non-null  float64
#  2   installment           396030 non-null  float64
#  3   annual_inc            396030 non-null  float64
#  4   dti                   396030 non-null  float64
#  5   open_acc              396030 non-null  float64
#  6   pub_rec               396030 non-null  float64
#  7   revol_bal             396030 non-null  float64
#  8   revol_util            395754 non-null  float64
#  9   total_acc             396030 non-null  float64
#  10  mort_acc              358235 non-null  float64
#  11  pub_rec_bankruptcies  395495 non-null  float64
# dtypes: float64(12)
# memory usage: 36.3 MB

# %% [markdown]
# ### annual_inc

# %%
info[info.LoanStatNew=='annual_inc'].Description
# Out:
# 9    The self-reported annual income provided by the borrower during registration.
# Name: Description, dtype: object

# %%
data1.annual_inc.describe()
# Out:
# count    3.960300e+05
# mean     7.420318e+04
# std      6.163762e+04
# min      0.000000e+00
# 25%      4.500000e+04
# 50%      6.400000e+04
# 75%      9.000000e+04
# max      8.706582e+06
# Name: annual_inc, dtype: float64

# %%
plt.figure(figsize=(12,10))
sns.histplot(data1.annual_inc,bins=100)
# Out:
# <AxesSubplot:xlabel='annual_inc', ylabel='Count'>

# %%
plt.figure(figsize=(12,10))
sns.histplot(np.log1p(data1.annual_inc),bins=100)
# Out:
# <AxesSubplot:xlabel='annual_inc', ylabel='Count'>

# %%
data1[data1.annual_inc<200000].annual_inc.value_counts()
# Out:
# 60000.00     15313
# 50000.00     13303
# 65000.00     11333
# 70000.00     10674
# 40000.00     10629
#              ...
# 111286.00        1
# 49577.60         1
# 49551.00         1
# 69779.00         1
# 31789.88         1
# Name: annual_inc, Length: 26501, dtype: int64

# %%
len(data1[data1.annual_inc<300000])/len(data1)*100
# Out:
# 99.42403353281317

# %% [markdown]
# #### Histplot of annual_inc less than 300000 (99.42% of data)

# %%
plt.figure(figsize=(12,10))
sns.histplot(data1[data1.annual_inc<300000].annual_inc,bins=100)
# Out:
# <AxesSubplot:xlabel='annual_inc', ylabel='Count'>

# %% [markdown]
# **Bivariate plot**

# %%
plt.figure(figsize=(12,10))
sns.histplot(data1[data1.annual_inc<300000],x='annual_inc',hue='loan_status',bins=100,palette='hot_r')
# Out:
# <AxesSubplot:xlabel='annual_inc', ylabel='Count'>

# %% [markdown]
# ### dti

# %%
info[info.LoanStatNew=='dti'].Description
# Out:
# 17    A ratio calculated using the borrower’s total monthly debt payments on the total debt obligations, excluding mortgage and the requested LC loan, divided by the borrower’s self-reported monthly income.
# Name: Description, dtype: object

# %%
data1.dti.describe()
# Out:
# count    396030.000000
# mean         17.379514
# std          18.019092
# min           0.000000
# 25%          11.280000
# 50%          16.910000
# 75%          22.980000
# max        9999.000000
# Name: dti, dtype: float64

# %%
plt.figure(figsize=(12,10))
sns.histplot(data1.dti,bins=100)
# Out:
# <AxesSubplot:xlabel='dti', ylabel='Count'>

# %%
plt.figure(figsize=(12,10))
sns.histplot(np.log1p(data1.dti),bins=100)
# Out:
# <AxesSubplot:xlabel='dti', ylabel='Count'>

# %%
data1[data1.dti<50].dti.describe()
# Out:
# count    395995.000000
# mean         17.344702
# std           8.119597
# min           0.000000
# 25%          11.280000
# 50%          16.900000
# 75%          22.980000
# max          49.830000
# Name: dti, dtype: float64

# %%
len(data1[data1.dti<50])/len(data1)*100
# Out:
# 99.99116228568543

# %% [markdown]
# #### Histplot of dti less than 50 (99.99% of data)

# %%
plt.figure(figsize=(12,10))
sns.histplot(data1[data1.dti<50].dti,bins=100)
# Out:
# <AxesSubplot:xlabel='dti', ylabel='Count'>

# %% [markdown]
# **Bivariate plot**

# %%
plt.figure(figsize=(12,10))
sns.histplot(data1[data1.dti<50],x='dti',hue='loan_status',bins=100,palette='hot_r')
# Out:
# <AxesSubplot:xlabel='dti', ylabel='Count'>

# %% [markdown]
# ### revol_bal

# %%
info[info.LoanStatNew=='revol_bal'].Description
# Out:
# 21    Total credit revolving balance
# Name: Description, dtype: object

# %%
data1.revol_bal.describe()
# Out:
# count    3.960300e+05
# mean     1.584454e+04
# std      2.059184e+04
# min      0.000000e+00
# 25%      6.025000e+03
# 50%      1.118100e+04
# 75%      1.962000e+04
# max      1.743266e+06
# Name: revol_bal, dtype: float64

# %%
plt.figure(figsize=(12,10))
sns.histplot(data1.revol_bal,bins=100)
# Out:
# <AxesSubplot:xlabel='revol_bal', ylabel='Count'>

# %%
plt.figure(figsize=(12,10))
sns.histplot(np.log1p(data1.revol_bal),bins=100)
# Out:
# <AxesSubplot:xlabel='revol_bal', ylabel='Count'>

# %%
len(data1[data1.revol_bal<100000])/len(data1)*100
# Out:
# 99.25308688735703

# %% [markdown]
# **Null values**

# %%
data1.revol_util.isna().sum()
# Out:
# 276

# %%
sum(data1.revol_util.notna())
# Out:
# 395754

# %%
len(data1)
# Out:
# 396030

# %%
len(data1[data1.revol_bal<100000])/sum(data1.revol_util.notna())*100
# Out:
# 99.32230628117466

# %% [markdown]
# #### Histplot of revol_bal<100000 (99.32% of data)

# %%
plt.figure(figsize=(12,10))
sns.histplot(data1[data1.revol_bal<100000].revol_bal,bins=100)
# Out:
# <AxesSubplot:xlabel='revol_bal', ylabel='Count'>

# %% [markdown]
# **Bivariate plot**

# %%
plt.figure(figsize=(12,10))
sns.histplot(data1[data1.revol_bal<100000],x='revol_bal',hue='loan_status',bins=100,palette='hot_r')
# Out:
# <AxesSubplot:xlabel='revol_bal', ylabel='Count'>

# %% [markdown]
# ### revol_util

# %%
info[info.LoanStatNew=='revol_util'].Description
# Out:
# 22    Revolving line utilization rate, or the amount of credit the borrower is using relative to all available revolving credit.
# Name: Description, dtype: object

# %%
data1.revol_util.describe()
# Out:
# count    395754.000000
# mean         53.791749
# std          24.452193
# min           0.000000
# 25%          35.800000
# 50%          54.800000
# 75%          72.900000
# max         892.300000
# Name: revol_util, dtype: float64

# %%
plt.figure(figsize=(12,10))
sns.histplot(data1.revol_util,bins=100)
# Out:
# <AxesSubplot:xlabel='revol_util', ylabel='Count'>

# %%
plt.figure(figsize=(12,10))
sns.histplot(np.log1p(data1.revol_util),bins=100)
# Out:
# <AxesSubplot:xlabel='revol_util', ylabel='Count'>

# %%
len(data1[data1.revol_util<150])/len(data1)*100
# Out:
# 99.92929828548343

# %% [markdown]
# #### Histplot of revol_util<150 (99.93% of data)

# %%
plt.figure(figsize=(12,10))
sns.histplot(data1[data1.revol_util<150].revol_util,bins=100)
# Out:
# <AxesSubplot:xlabel='revol_util', ylabel='Count'>

# %% [markdown]
# **Bivariate plot**

# %%
plt.figure(figsize=(12,10))
sns.histplot(data1[data1.revol_util<150],x='revol_util',hue='loan_status',bins=100,palette='hot_r')
# Out:
# <AxesSubplot:xlabel='revol_util', ylabel='Count'>

# %% [markdown]
# ### mort_acc

# %%
info[info.LoanStatNew=='mort_acc'].Description
# Out:
# 26    Number of mortgage accounts.
# Name: Description, dtype: object

# %%
data1.mort_acc.describe()
# Out:
# count    358235.000000
# mean          1.813991
# std           2.147930
# min           0.000000
# 25%           0.000000
# 50%           1.000000
# 75%           3.000000
# max          34.000000
# Name: mort_acc, dtype: float64

# %%
plt.figure(figsize=(12,10))
sns.histplot(data1.mort_acc,bins=100)
# Out:
# <AxesSubplot:xlabel='mort_acc', ylabel='Count'>

# %%
plt.figure(figsize=(12,10))
sns.histplot(np.log1p(data1.mort_acc),bins=100)
# Out:
# <AxesSubplot:xlabel='mort_acc', ylabel='Count'>

# %%
len(data1[data1.mort_acc<13])/len(data1)
# Out:
# 0.9034088326641921

# %% [markdown]
# **Null values**

# %%
data1.mort_acc.isna().sum()
# Out:
# 37795

# %%
data1.mort_acc.notna().sum()
# Out:
# 358235

# %%
len(data1[data1.mort_acc<13])/data1.mort_acc.notna().sum()
# Out:
# 0.9987215096235711

# %% [markdown]
# #### Histplot of mort_acc<13 (99.87% of data)

# %%
plt.figure(figsize=(12,10))
sns.histplot(data1[data1.mort_acc<13].mort_acc,bins=13)
# Out:
# <AxesSubplot:xlabel='mort_acc', ylabel='Count'>

# %% [markdown]
# **Bivariate plot**

# %%
plt.figure(figsize=(12,10))
sns.histplot(data1[data1.mort_acc<13],x='mort_acc',hue='loan_status',bins=13,palette='hot_r',multiple='dodge')
# Out:
# <AxesSubplot:xlabel='mort_acc', ylabel='Count'>

# %% [markdown]
# ## Categorical Features

# %%
data1.select_dtypes('object').info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 396030 entries, 0 to 396029
# Data columns (total 14 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   term                 396030 non-null  object
#  1   grade                396030 non-null  object
#  2   sub_grade            396030 non-null  object
#  3   emp_title            373103 non-null  object
#  4   emp_length           377729 non-null  object
#  5   home_ownership       396030 non-null  object
#  6   verification_status  396030 non-null  object
#  7   issue_d              396030 non-null  object
#  8   purpose              396030 non-null  object
#  9   title                394275 non-null  object
#  10  earliest_cr_line     396030 non-null  object
#  11  initial_list_status  396030 non-null  object
#  12  application_type     396030 non-null  object
#  13  address              396030 non-null  object
# dtypes: object(14)
# memory usage: 42.3+ MB

# %% [markdown]
# ### 1. term

# %%
info[info.LoanStatNew=='term'].Description
# Out:
# 1    The number of payments on the loan. Values are in months and can be either 36 or 60.
# Name: Description, dtype: object

# %%
data1.term.describe()
# Out:
# count         396030
# unique             2
# top        36 months
# freq          302005
# Name: term, dtype: object

# %%
plt.figure(figsize=(12,10))
sns.countplot(data=data1,x='term')
# Out:
# <AxesSubplot:xlabel='term', ylabel='count'>

# %% [markdown]
# **Bivariate plot**

# %%
plt.figure(figsize=(12,10))
sns.countplot(data=data1,x='term',hue='loan_status',palette='hot_r')
# Out:
# <AxesSubplot:xlabel='term', ylabel='count'>

# %% [markdown]
# ### 2. grade

# %%
info[info.LoanStatNew=='grade'].Description
# Out:
# 4    LC assigned loan grade
# Name: Description, dtype: object

# %%
data1.grade.describe()
# Out:
# count     396030
# unique         7
# top            B
# freq      116018
# Name: grade, dtype: object

# %%
grades=sorted(data1.grade.unique())

# %%
plt.figure(figsize=(12,10))
sns.countplot(data=data1,x='grade',order=grades)
# Out:
# <AxesSubplot:xlabel='grade', ylabel='count'>

# %% [markdown]
# **Bivariate plot**

# %%
plt.figure(figsize=(12,10))
sns.countplot(data=data1,x='grade',hue='loan_status',palette='hot_r',order=grades)
# Out:
# <AxesSubplot:xlabel='grade', ylabel='count'>

# %% [markdown]
# ### 3. sub_grade

# %%
info[info.LoanStatNew=='sub_grade'].Description
# Out:
# 5    LC assigned loan subgrade
# Name: Description, dtype: object

# %%
data1.sub_grade.describe()
# Out:
# count     396030
# unique        35
# top           B3
# freq       26655
# Name: sub_grade, dtype: object

# %%
sub_grades=sorted(data1.sub_grade.unique())

# %%
plt.figure(figsize=(20,10))
sns.countplot(data=data1,x='sub_grade',order=sub_grades)
# Out:
# <AxesSubplot:xlabel='sub_grade', ylabel='count'>

# %% [markdown]
# **Bivariate plot**

# %%
plt.figure(figsize=(20,10))
sns.countplot(data=data1,x='sub_grade',hue='loan_status',palette='hot_r',order=sub_grades)
# Out:
# <AxesSubplot:xlabel='sub_grade', ylabel='count'>

# %% [markdown]
# ### 4. emp_title

# %%
info[info.LoanStatNew=='emp_title'].Description
# Out:
# 6    The job title supplied by the Borrower when applying for the loan.*
# Name: Description, dtype: object

# %%
data1.emp_title.describe()
# Out:
# count      373103
# unique     173105
# top       Teacher
# freq         4389
# Name: emp_title, dtype: object

# %%
data1.emp_title.head()
# Out:
# 0                  Marketing
# 1            Credit analyst
# 2               Statistician
# 3            Client Advocate
# 4    Destiny Management Inc.
# Name: emp_title, dtype: object

# %%
data1.emp_title.value_counts()
# Out:
# Teacher                    4389
# Manager                    4250
# Registered Nurse           1856
# RN                         1846
# Supervisor                 1830
#                            ...
# Postman                       1
# McCarthy & Holthus, LLC       1
# jp flooring                   1
# Histology Technologist        1
# Gracon Services, Inc          1
# Name: emp_title, Length: 173105, dtype: int64

# %% [markdown]
# **emp_title with atleast 100 repetitions : 268**

# %%
emp_title_df=data1.emp_title.value_counts()
emp_title_df[emp_title_df>100]
# Out:
# Teacher                4389
# Manager                4250
# Registered Nurse       1856
# RN                     1846
# Supervisor             1830
#                        ...
# COO                     102
# Bus Operator            102
# Graphic Designer        102
# tech                    101
# Associate Professor     101
# Name: emp_title, Length: 268, dtype: int64

# %% [markdown]
# **Too many categories. Irrelevant feature**

# %% [markdown]
# ### 5. emp_length

# %%
info[info.LoanStatNew=='emp_length'].Description
# Out:
# 7    Employment length in years. Possible values are between 0 and 10 where 0 means less than one year and 10 means ten or more years.
# Name: Description, dtype: object

# %%
data1.emp_length.describe()
# Out:
# count        377729
# unique           11
# top       10+ years
# freq         126041
# Name: emp_length, dtype: object

# %% [markdown]
# **sorting**

# %%
emp_lengths=sorted(data1.emp_length.astype(str).unique())
emp_lengths
# Out:
# ['1 year',
#  '10+ years',
#  '2 years',
#  '3 years',
#  '4 years',
#  '5 years',
#  '6 years',
#  '7 years',
#  '8 years',
#  '9 years',
#  '< 1 year',
#  'nan']

# %%
emp_lengths[0],emp_lengths[1],emp_lengths[-2]=emp_lengths[-2],emp_lengths[0],emp_lengths[1]
emp_lengths
# Out:
# ['< 1 year',
#  '1 year',
#  '2 years',
#  '3 years',
#  '4 years',
#  '5 years',
#  '6 years',
#  '7 years',
#  '8 years',
#  '9 years',
#  '10+ years',
#  'nan']

# %%
plt.figure(figsize=(15,10))
sns.countplot(data=data1,x='emp_length',order=emp_lengths)
# Out:
# <AxesSubplot:xlabel='emp_length', ylabel='count'>

# %% [markdown]
# **Bivariate plot**

# %%
plt.figure(figsize=(20,10))
sns.countplot(data=data1,x='emp_length',hue='loan_status',palette='hot_r',order=emp_lengths)
# Out:
# <AxesSubplot:xlabel='emp_length', ylabel='count'>

# %% [markdown]
# **Target variable distribution is similar in different emp_length**

# %%
emp_lengths_df=data1.groupby('emp_length').loan_status.mean()
emp_lengths_df
# Out:
# emp_length
# 1 year       0.800865
# 10+ years    0.815814
# 2 years      0.806738
# 3 years      0.804769
# 4 years      0.807615
# 5 years      0.807813
# 6 years      0.810806
# 7 years      0.805226
# 8 years      0.800240
# 9 years      0.799530
# < 1 year     0.793128
# Name: loan_status, dtype: float64

# %% [markdown]
# ### 6. home_ownership

# %%
info[info.LoanStatNew=='home_ownership'].Description
# Out:
# 8    The home ownership status provided by the borrower during registration or obtained from the credit report. Our values are: RENT, OWN, MORTGAGE, OTHER
# Name: Description, dtype: object

# %%
data1.home_ownership.describe()
# Out:
# count       396030
# unique           6
# top       MORTGAGE
# freq        198348
# Name: home_ownership, dtype: object

# %%
plt.figure(figsize=(12,10))
sns.countplot(data=data1,x='home_ownership')
# Out:
# <AxesSubplot:xlabel='home_ownership', ylabel='count'>

# %% [markdown]
# **Bivariate plot**

# %%
plt.figure(figsize=(20,10))
sns.countplot(data=data1,x='home_ownership',hue='loan_status',palette='hot_r')
# Out:
# <AxesSubplot:xlabel='home_ownership', ylabel='count'>

# %%
data1.home_ownership.value_counts()
# Out:
# MORTGAGE    198348
# RENT        159790
# OWN          37746
# OTHER          112
# NONE            31
# ANY              3
# Name: home_ownership, dtype: int64

# %% [markdown]
# **Percentage value_counts**

# %%
data1.home_ownership.value_counts(normalize=True)*100
# Out:
# MORTGAGE    50.084085
# RENT        40.347953
# OWN          9.531096
# OTHER        0.028281
# NONE         0.007828
# ANY          0.000758
# Name: home_ownership, dtype: float64

# %% [markdown]
# **Need data cleaning**

# %% [markdown]
# ### 7. verification_status

# %%
info[info.LoanStatNew=='verification_status'].Description
# Out:
# 10    Indicates if income was verified by LC, not verified, or if the income source was verified
# Name: Description, dtype: object

# %%
data1.verification_status.describe()
# Out:
# count       396030
# unique           3
# top       Verified
# freq        139563
# Name: verification_status, dtype: object

# %%
plt.figure(figsize=(12,10))
sns.countplot(data=data1,x='verification_status')
# Out:
# <AxesSubplot:xlabel='verification_status', ylabel='count'>

# %% [markdown]
# **Bivariate plot**

# %%
plt.figure(figsize=(20,10))
sns.countplot(data=data1,x='verification_status',hue='loan_status',palette='hot_r')
# Out:
# <AxesSubplot:xlabel='verification_status', ylabel='count'>

# %% [markdown]
# ### 8. issue_d

# %%
info[info.LoanStatNew=='issue_d'].Description
# Out:
# 11    The month which the loan was funded
# Name: Description, dtype: object

# %%
data1.issue_d.describe()
# Out:
# count       396030
# unique         115
# top       Oct-2014
# freq         14846
# Name: issue_d, dtype: object

# %% [markdown]
# **Not available realistically before loan decision. Need to be dropped to prevent data leakage**

# %% [markdown]
# ### 9. purpose

# %%
info[info.LoanStatNew=='purpose'].Description
# Out:
# 13    A category provided by the borrower for the loan request.
# Name: Description, dtype: object

# %%
data1.purpose.describe()
# Out:
# count                 396030
# unique                    14
# top       debt_consolidation
# freq                  234507
# Name: purpose, dtype: object

# %%
plt.figure(figsize=(12,10))
sns.countplot(data=data1,y='purpose')
# Out:
# <AxesSubplot:xlabel='count', ylabel='purpose'>

# %% [markdown]
# **Bivariate plot**

# %%
plt.figure(figsize=(15,15))
sns.countplot(data=data1,y='purpose',hue='loan_status',palette='hot_r')
# Out:
# <AxesSubplot:xlabel='count', ylabel='purpose'>

# %% [markdown]
# ### 10. title

# %%
info[info.LoanStatNew=='title'].Description
# Out:
# 14    The loan title provided by the borrower
# Name: Description, dtype: object

# %%
data1.title.describe()
# Out:
# count                 394275
# unique                 48817
# top       Debt consolidation
# freq                  152472
# Name: title, dtype: object

# %%
data1.title.head()
# Out:
# 0                   Vacation
# 1         Debt consolidation
# 2    Credit card refinancing
# 3    Credit card refinancing
# 4      Credit Card Refinance
# Name: title, dtype: object

# %%
data1.title.value_counts()
# Out:
# Debt consolidation            152472
# Credit card refinancing        51487
# Home improvement               15264
# Other                          12930
# Debt Consolidation             11608
#                                ...
# Graduation/Travel Expenses         1
# Daughter's Wedding Bill            1
# gotta move                         1
# creditcardrefi                     1
# Toxic Debt Payoff                  1
# Name: title, Length: 48817, dtype: int64

# %% [markdown]
# **title with atleast 100 repetitions : 138**

# %%
title_df=data1.title.value_counts()
title_df[title_df>100]
# Out:
# Debt consolidation         152472
# Credit card refinancing     51487
# Home improvement            15264
# Other                       12930
# Debt Consolidation          11608
#                             ...
# Refi                          105
# Debt Relief                   103
# Debt loan                     103
# Credit                        101
# Credit card                   101
# Name: title, Length: 138, dtype: int64

# %% [markdown]
# **Too many categories. Irrelevant feature**

# %% [markdown]
# ### 11. earliest_cr_line

# %%
info[info.LoanStatNew=='earliest_cr_line'].Description
# Out:
# 18    The month the borrower's earliest reported credit line was opened
# Name: Description, dtype: object

# %%
data1.earliest_cr_line.describe()
# Out:
# count       396030
# unique         684
# top       Oct-2000
# freq          3017
# Name: earliest_cr_line, dtype: object

# %%
data1.earliest_cr_line.head()
# Out:
# 0    Jun-1990
# 1    Jul-2004
# 2    Aug-2007
# 3    Sep-2006
# 4    Mar-1999
# Name: earliest_cr_line, dtype: object

# %% [markdown]
# **Could be feature engineered**

# %% [markdown]
# ### 12. initial_list_status

# %%
info[info.LoanStatNew=='initial_list_status'].Description
# Out:
# 24    The initial listing status of the loan. Possible values are – W, F
# Name: Description, dtype: object

# %%
data1.initial_list_status.describe()
# Out:
# count     396030
# unique         2
# top            f
# freq      238066
# Name: initial_list_status, dtype: object

# %%
plt.figure(figsize=(12,10))
sns.countplot(data=data1,x='initial_list_status')
# Out:
# <AxesSubplot:xlabel='initial_list_status', ylabel='count'>

# %% [markdown]
# **Bivariate plot**

# %%
plt.figure(figsize=(20,10))
sns.countplot(data=data1,x='initial_list_status',hue='loan_status',palette='hot_r')
# Out:
# <AxesSubplot:xlabel='initial_list_status', ylabel='count'>

# %% [markdown]
# ### 13. application_type

# %%
info[info.LoanStatNew=='application_type'].Description
# Out:
# 25    Indicates whether the loan is an individual application or a joint application with two co-borrowers
# Name: Description, dtype: object

# %%
data1.application_type.describe()
# Out:
# count         396030
# unique             3
# top       INDIVIDUAL
# freq          395319
# Name: application_type, dtype: object

# %%
plt.figure(figsize=(12,10))
sns.countplot(data=data1,x='application_type')
# Out:
# <AxesSubplot:xlabel='application_type', ylabel='count'>

# %% [markdown]
# **Bivariate plot**

# %%
plt.figure(figsize=(20,10))
sns.countplot(data=data1,x='application_type',hue='loan_status',palette='hot_r')
# Out:
# <AxesSubplot:xlabel='application_type', ylabel='count'>

# %% [markdown]
# **Target variable distribution is similar in different application_type**

# %%
application_type_df=data1.groupby('application_type').loan_status.mean()
application_type_df
# Out:
# application_type
# DIRECT_PAY    0.643357
# INDIVIDUAL    0.803913
# JOINT         0.872941
# Name: loan_status, dtype: float64

# %%
data1.application_type.value_counts()
# Out:
# INDIVIDUAL    395319
# JOINT            425
# DIRECT_PAY       286
# Name: application_type, dtype: int64

# %% [markdown]
# **Percentage value_counts**

# %%
data1.application_type.value_counts(normalize=True)*100
# Out:
# INDIVIDUAL    99.820468
# JOINT          0.107315
# DIRECT_PAY     0.072217
# Name: application_type, dtype: float64

# %% [markdown]
# ### 14. address

# %%
info[info.LoanStatNew=='address'].Description
# Out:
# Series([], Name: Description, dtype: object)

# %%
data1.address.head()
# Out:
# 0       0174 Michelle Gateway\nMendozaberg, OK 22690
# 1    1076 Carney Fort Apt. 347\nLoganmouth, SD 05113
# 2    87025 Mark Dale Apt. 269\nNew Sabrina, WV 05113
# 3              823 Reid Ford\nDelacruzside, MA 00813
# 4               679 Luna Roads\nGreggshire, VA 11650
# Name: address, dtype: object

# %%
data1.address.describe()
# Out:
# count                        396030
# unique                       393700
# top       USCGC Smith\nFPO AE 70466
# freq                              8
# Name: address, dtype: object

# %%
data1.address.value_counts()
# Out:
# USCGC Smith\nFPO AE 70466                           8
# USS Johnson\nFPO AE 48052                           8
# USNS Johnson\nFPO AE 05113                          8
# USS Smith\nFPO AP 70466                             8
# USNS Johnson\nFPO AP 48052                          7
#                                                    ..
# 455 Tricia Cove\nAustinbury, FL 00813               1
# 7776 Flores Fall\nFernandezshire, UT 05113          1
# 6577 Mia Harbors Apt. 171\nRobertshire, OK 22690    1
# 8141 Cox Greens Suite 186\nMadisonstad, VT 05113    1
# 787 Michelle Causeway\nBriannaton, AR 48052         1
# Name: address, Length: 393700, dtype: int64

# %% [markdown]
# **Zip codes can be feature engineered**

# %% [markdown]
# ## Correlations of categorical features

# %% [markdown]
# ### 1. term

# %% [markdown]
# #### Bivariate plot showing label ratios

# %%
plt.figure(figsize=(8,10))
sns.histplot(data=data1,x='term',hue='loan_status',palette='hot_r',multiple='fill')
# Out:
# <AxesSubplot:xlabel='term', ylabel='Count'>

# %% [markdown]
# #### Target variable distribution in different term

# %%
term_df=data1.groupby('term').loan_status.mean()
term_df
# Out:
# term
#  36 months    0.842254
#  60 months    0.680585
# Name: loan_status, dtype: float64

# %% [markdown]
# **Label distribution is different**

# %% [markdown]
# ### 2. grade

# %% [markdown]
# #### Bivariate plot showing label ratios

# %%
plt.figure(figsize=(12,10))
sns.histplot(data=data1,x='grade',hue='loan_status',palette='hot_r',multiple='fill')
# Out:
# <AxesSubplot:xlabel='grade', ylabel='Count'>

# %% [markdown]
# #### Target variable distribution in different grade

# %%
grade_df=data1.groupby('grade').loan_status.mean()
grade_df
# Out:
# grade
# A    0.937121
# B    0.874270
# C    0.788191
# D    0.711322
# E    0.626366
# F    0.572120
# G    0.521611
# Name: loan_status, dtype: float64

# %% [markdown]
# **Label distribution is different**

# %% [markdown]
# ### 3. sub_grade

# %% [markdown]
# #### Bivariate plot showing label ratios

# %%
plt.figure(figsize=(20,10))
sns.histplot(data=data1,x='sub_grade',hue='loan_status',palette='hot_r',multiple='fill')
# Out:
# <AxesSubplot:xlabel='sub_grade', ylabel='Count'>

# %% [markdown]
# #### Target variable distribution in different sub_grade

# %%
sub_grade_df=data1.groupby('sub_grade').loan_status.mean()
sub_grade_df
# Out:
# sub_grade
# A1    0.971323
# A2    0.951814
# A3    0.941944
# A4    0.929761
# A5    0.915092
# B1    0.901418
# B2    0.891487
# B3    0.876646
# B4    0.861607
# B5    0.844963
# C1    0.826304
# C2    0.802480
# C3    0.781584
# C4    0.764645
# C5    0.754933
# D1    0.736197
# D2    0.719662
# D3    0.715782
# D4    0.688685
# D5    0.679897
# E1    0.655930
# E2    0.632620
# E3    0.619623
# E4    0.606976
# E5    0.596894
# F1    0.612557
# F2    0.575199
# F3    0.563867
# F4    0.543928
# F5    0.513243
# G1    0.538752
# G2    0.517241
# G3    0.489130
# G4    0.550802
# G5    0.496835
# Name: loan_status, dtype: float64

# %% [markdown]
# **Label distribution is different**

# %% [markdown]
# ### 4. emp_length

# %% [markdown]
# #### Bivariate plot showing label ratios

# %%
plt.figure(figsize=(20,10))
sns.histplot(data=data1,x='emp_length',hue='loan_status',palette='hot_r',multiple='fill')
# Out:
# <AxesSubplot:xlabel='emp_length', ylabel='Count'>

# %% [markdown]
# #### Target variable distribution is similar in different emp_length

# %%
emp_lengths_df=data1.groupby('emp_length').loan_status.mean()
emp_lengths_df
# Out:
# emp_length
# 1 year       0.800865
# 10+ years    0.815814
# 2 years      0.806738
# 3 years      0.804769
# 4 years      0.807615
# 5 years      0.807813
# 6 years      0.810806
# 7 years      0.805226
# 8 years      0.800240
# 9 years      0.799530
# < 1 year     0.793128
# Name: loan_status, dtype: float64

# %% [markdown]
# **Label distribution is very similar**

# %% [markdown]
# ### 5. home_ownership

# %% [markdown]
# #### Bivariate plot showing label ratios

# %%
plt.figure(figsize=(20,10))
sns.histplot(data=data1,x='home_ownership',hue='loan_status',palette='hot_r',multiple='fill')
# Out:
# <AxesSubplot:xlabel='home_ownership', ylabel='Count'>

# %% [markdown]
# #### Target variable distribution in different home_ownership

# %%
home_ownership_df=data1.groupby('home_ownership').loan_status.mean()
home_ownership_df
# Out:
# home_ownership
# ANY         1.000000
# MORTGAGE    0.830439
# NONE        0.774194
# OTHER       0.857143
# OWN         0.793197
# RENT        0.773378
# Name: loan_status, dtype: float64

# %% [markdown]
# **Label distribution is slightly different**

# %% [markdown]
# ### 6. verification_status

# %% [markdown]
# #### Bivariate plot showing label ratios

# %%
plt.figure(figsize=(10,10))
sns.histplot(data=data1,x='verification_status',hue='loan_status',palette='hot_r',multiple='fill')
# Out:
# <AxesSubplot:xlabel='verification_status', ylabel='Count'>

# %% [markdown]
# #### Target variable distribution in different verification_status

# %%
verification_status_df=data1.groupby('verification_status').loan_status.mean()
verification_status_df
# Out:
# verification_status
# Not Verified       0.853640
# Source Verified    0.785257
# Verified           0.776789
# Name: loan_status, dtype: float64

# %% [markdown]
# **Label distribution is slightly different**

# %% [markdown]
# ### 7. purpose

# %% [markdown]
# #### Bivariate plot showing label ratios

# %%
plt.figure(figsize=(15,15))
sns.histplot(data=data1,y='purpose',hue='loan_status',palette='hot_r',multiple='fill')
# Out:
# <AxesSubplot:xlabel='Count', ylabel='purpose'>

# %% [markdown]
# #### Target variable distribution in different purpose

# %%
purpose_df=data1.groupby('purpose').loan_status.mean()
purpose_df
# Out:
# purpose
# car                   0.865233
# credit_card           0.832882
# debt_consolidation    0.792586
# educational           0.836576
# home_improvement      0.829921
# house                 0.802817
# major_purchase        0.835267
# medical               0.782888
# moving                0.765242
# other                 0.787822
# renewable_energy      0.765957
# small_business        0.705490
# vacation              0.810767
# wedding               0.879139
# Name: loan_status, dtype: float64

# %% [markdown]
# **Label distribution is different**

# %% [markdown]
# ### 8. initial_list_status

# %% [markdown]
# #### Bivariate plot showing label ratios

# %%
plt.figure(figsize=(10,10))
sns.histplot(data=data1,x='initial_list_status',hue='loan_status',palette='hot_r',multiple='fill')
# Out:
# <AxesSubplot:xlabel='initial_list_status', ylabel='Count'>

# %% [markdown]
# #### Target variable distribution in different initial_list_status

# %%
initial_list_status_df=data1.groupby('initial_list_status').loan_status.mean()
initial_list_status_df
# Out:
# initial_list_status
# f    0.806940
# w    0.799245
# Name: loan_status, dtype: float64

# %% [markdown]
# **Label distribution is similar**

# %% [markdown]
# ### 9. application_type

# %% [markdown]
# #### Bivariate plot showing label ratios

# %%
plt.figure(figsize=(10,10))
sns.histplot(data=data1,x='application_type',hue='loan_status',palette='hot_r',multiple='fill')
# Out:
# <AxesSubplot:xlabel='application_type', ylabel='Count'>

# %% [markdown]
# #### Target variable distribution in different application_type

# %%
application_type_df=data1.groupby('application_type').loan_status.mean()
application_type_df
# Out:
# application_type
# DIRECT_PAY    0.643357
# INDIVIDUAL    0.803913
# JOINT         0.872941
# Name: loan_status, dtype: float64

# %% [markdown]
# **Label distribution is different**

# %% [markdown]
# # Feature Engineering

# %% [markdown]
# ## 1. Feature with dates : earliest_cr_line

# %%
info[info.LoanStatNew=='earliest_cr_line'].Description
# Out:
# 18    The month the borrower's earliest reported credit line was opened
# Name: Description, dtype: object

# %%
data1.earliest_cr_line.describe()
# Out:
# count       396030
# unique         684
# top       Oct-2000
# freq          3017
# Name: earliest_cr_line, dtype: object

# %%
data1.earliest_cr_line.head()
# Out:
# 0    Jun-1990
# 1    Jul-2004
# 2    Aug-2007
# 3    Sep-2006
# 4    Mar-1999
# Name: earliest_cr_line, dtype: object

# %% [markdown]
# ### Converting to date-time format

# %%
data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 396030 entries, 0 to 396029
# Data columns (total 27 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   loan_amnt             396030 non-null  float64
#  1   term                  396030 non-null  object
#  2   int_rate              396030 non-null  float64
#  3   installment           396030 non-null  float64
#  4   grade                 396030 non-null  object
#  5   sub_grade             396030 non-null  object
#  6   emp_title             373103 non-null  object
#  7   emp_length            377729 non-null  object
#  8   home_ownership        396030 non-null  object
#  9   annual_inc            396030 non-null  float64
#  10  verification_status   396030 non-null  object
#  11  issue_d               396030 non-null  object
#  12  loan_status           396030 non-null  uint8
#  13  purpose               396030 non-null  object
#  14  title                 394275 non-null  object
#  15  dti                   396030 non-null  float64
#  16  earliest_cr_line      396030 non-null  object
#  17  open_acc              396030 non-null  float64
#  18  pub_rec               396030 non-null  float64
#  19  revol_bal             396030 non-null  float64
#  20  revol_util            395754 non-null  float64
#  21  total_acc             396030 non-null  float64
#  22  initial_list_status   396030 non-null  object
#  23  application_type      396030 non-null  object
#  24  mort_acc              358235 non-null  float64
#  25  pub_rec_bankruptcies  395495 non-null  float64
#  26  address               396030 non-null  object
# dtypes: float64(12), object(14), uint8(1)
# memory usage: 78.9+ MB

# %%
data2=data1.copy()

# %%
data2.earliest_cr_line=pd.to_datetime(data2.earliest_cr_line)

# %% [markdown]
# ### Making month and year feature separate

# %%
data2['earliest_cr_line_month']=data2.earliest_cr_line.apply(lambda x:x.month)
data2.earliest_cr_line_month
# Out:
# 0          6
# 1          7
# 2          8
# 3          9
# 4          3
#           ..
# 396025    11
# 396026     2
# 396027     3
# 396028    11
# 396029     9
# Name: earliest_cr_line_month, Length: 396030, dtype: int64

# %%
data2['earliest_cr_line_year']=data2.earliest_cr_line.apply(lambda x:x.year)
data2.earliest_cr_line_year
# Out:
# 0         1990
# 1         2004
# 2         2007
# 3         2006
# 4         1999
#           ...
# 396025    2004
# 396026    2006
# 396027    1997
# 396028    1990
# 396029    1998
# Name: earliest_cr_line_year, Length: 396030, dtype: int64

# %%
data2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 396030 entries, 0 to 396029
# Data columns (total 29 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   loan_amnt               396030 non-null  float64
#  1   term                    396030 non-null  object
#  2   int_rate                396030 non-null  float64
#  3   installment             396030 non-null  float64
#  4   grade                   396030 non-null  object
#  5   sub_grade               396030 non-null  object
#  6   emp_title               373103 non-null  object
#  7   emp_length              377729 non-null  object
#  8   home_ownership          396030 non-null  object
#  9   annual_inc              396030 non-null  float64
#  10  verification_status     396030 non-null  object
#  11  issue_d                 396030 non-null  object
#  12  loan_status             396030 non-null  uint8
#  13  purpose                 396030 non-null  object
#  14  title                   394275 non-null  object
#  15  dti                     396030 non-null  float64
#  16  earliest_cr_line        396030 non-null  datetime64[ns]
#  17  open_acc                396030 non-null  float64
#  18  pub_rec                 396030 non-null  float64
#  19  revol_bal               396030 non-null  float64
#  20  revol_util              395754 non-null  float64
#  21  total_acc               396030 non-null  float64
#  22  initial_list_status     396030 non-null  object
#  23  application_type        396030 non-null  object
#  24  mort_acc                358235 non-null  float64
#  25  pub_rec_bankruptcies    395495 non-null  float64
#  26  address                 396030 non-null  object
#  27  earliest_cr_line_month  396030 non-null  int64
#  28  earliest_cr_line_year   396030 non-null  int64
# dtypes: datetime64[ns](1), float64(12), int64(2), object(13), uint8(1)
# memory usage: 85.0+ MB

# %% [markdown]
# ### Dropping original date-time features

# %%
data2.drop('earliest_cr_line',axis=1,inplace=True)
data2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 396030 entries, 0 to 396029
# Data columns (total 28 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   loan_amnt               396030 non-null  float64
#  1   term                    396030 non-null  object
#  2   int_rate                396030 non-null  float64
#  3   installment             396030 non-null  float64
#  4   grade                   396030 non-null  object
#  5   sub_grade               396030 non-null  object
#  6   emp_title               373103 non-null  object
#  7   emp_length              377729 non-null  object
#  8   home_ownership          396030 non-null  object
#  9   annual_inc              396030 non-null  float64
#  10  verification_status     396030 non-null  object
#  11  issue_d                 396030 non-null  object
#  12  loan_status             396030 non-null  uint8
#  13  purpose                 396030 non-null  object
#  14  title                   394275 non-null  object
#  15  dti                     396030 non-null  float64
#  16  open_acc                396030 non-null  float64
#  17  pub_rec                 396030 non-null  float64
#  18  revol_bal               396030 non-null  float64
#  19  revol_util              395754 non-null  float64
#  20  total_acc               396030 non-null  float64
#  21  initial_list_status     396030 non-null  object
#  22  application_type        396030 non-null  object
#  23  mort_acc                358235 non-null  float64
#  24  pub_rec_bankruptcies    395495 non-null  float64
#  25  address                 396030 non-null  object
#  26  earliest_cr_line_month  396030 non-null  int64
#  27  earliest_cr_line_year   396030 non-null  int64
# dtypes: float64(12), int64(2), object(13), uint8(1)
# memory usage: 82.0+ MB

# %% [markdown]
# ## 2. Checking if grade and subgrade are linked

# %% [markdown]
# ### 1. grade=='A'

# %%
data2[data2.grade=='A'].sub_grade.value_counts()
# Out:
# A5    18526
# A4    15789
# A3    10576
# A1     9729
# A2     9567
# Name: sub_grade, dtype: int64

# %% [markdown]
# ### 2. grade=='B'

# %%
data2[data2.grade=='B'].sub_grade.value_counts()
# Out:
# B3    26655
# B4    25601
# B2    22495
# B5    22085
# B1    19182
# Name: sub_grade, dtype: int64

# %% [markdown]
# ### 3. grade=='C'

# %%
data2[data2.grade=='C'].sub_grade.value_counts()
# Out:
# C1    23662
# C2    22580
# C3    21221
# C4    20280
# C5    18244
# Name: sub_grade, dtype: int64

# %% [markdown]
# ### 4. grade=='D'

# %%
data2[data2.grade=='D'].sub_grade.value_counts()
# Out:
# D1    15993
# D2    13951
# D3    12223
# D4    11657
# D5     9700
# Name: sub_grade, dtype: int64

# %% [markdown]
# ### 5. grade=='E'

# %%
data2[data2.grade=='E'].sub_grade.value_counts()
# Out:
# E1    7917
# E2    7431
# E3    6207
# E4    5361
# E5    4572
# Name: sub_grade, dtype: int64

# %% [markdown]
# ### 6. grade=='F'

# %%
data2[data2.grade=='F'].sub_grade.value_counts()
# Out:
# F1    3536
# F2    2766
# F3    2286
# F4    1787
# F5    1397
# Name: sub_grade, dtype: int64

# %% [markdown]
# ### 7. grade=='G'

# %%
data2[data2.grade=='G'].sub_grade.value_counts()
# Out:
# G1    1058
# G2     754
# G3     552
# G4     374
# G5     316
# Name: sub_grade, dtype: int64

# %% [markdown]
# **grade and sub_grade are related features**

# %% [markdown]
# ## Removing grade info from sub_grade

# %%
data3=data2.copy()

# %%
data3.sub_grade=data3.sub_grade.apply(lambda x:x[1])

# %%
data3.sub_grade.head()
# Out:
# 0    4
# 1    5
# 2    3
# 3    2
# 4    5
# Name: sub_grade, dtype: object

# %% [markdown]
# ## 3. Getting zipcodes from address

# %%
data4=data3.copy()

# %%
info[info.LoanStatNew=='address'].Description
# Out:
# Series([], Name: Description, dtype: object)

# %%
data4.address.head()
# Out:
# 0       0174 Michelle Gateway\nMendozaberg, OK 22690
# 1    1076 Carney Fort Apt. 347\nLoganmouth, SD 05113
# 2    87025 Mark Dale Apt. 269\nNew Sabrina, WV 05113
# 3              823 Reid Ford\nDelacruzside, MA 00813
# 4               679 Luna Roads\nGreggshire, VA 11650
# Name: address, dtype: object

# %%
data4.address.describe()
# Out:
# count                        396030
# unique                       393700
# top       USCGC Smith\nFPO AE 70466
# freq                              8
# Name: address, dtype: object

# %%
data4.address=data4.address.apply(lambda x:x[-5:])

# %%
data4.address.head()
# Out:
# 0    22690
# 1    05113
# 2    05113
# 3    00813
# 4    11650
# Name: address, dtype: object

# %% [markdown]
# ## EDA of new features

# %% [markdown]
# ### 1. earliest_cr_line_month

# %%
data4.earliest_cr_line_month.value_counts()
# Out:
# 10    38291
# 9     37673
# 8     37349
# 11    35583
# 12    33687
# 7     31972
# 3     31617
# 1     30694
# 6     30445
# 5     30445
# 4     29231
# 2     29043
# Name: earliest_cr_line_month, dtype: int64

# %%
plt.figure(figsize=(12,10))
sns.countplot(data=data4,x='earliest_cr_line_month')
# Out:
# <AxesSubplot:xlabel='earliest_cr_line_month', ylabel='count'>

# %% [markdown]
# ### 2. earliest_cr_line_year

# %%
data4.earliest_cr_line_year.value_counts()
# Out:
# 2000    29366
# 2001    29083
# 1999    26491
# 2002    25901
# 2003    23657
#         ...
# 1951        3
# 1950        3
# 1953        2
# 1944        1
# 1948        1
# Name: earliest_cr_line_year, Length: 65, dtype: int64

# %%
plt.figure(figsize=(12,10))
sns.histplot(data4.earliest_cr_line_year,bins=100)
# Out:
# <AxesSubplot:xlabel='earliest_cr_line_year', ylabel='Count'>

# %% [markdown]
# ### 3. sub_grade

# %%
data4.sub_grade.value_counts()
# Out:
# 1    81077
# 4    80849
# 3    79720
# 2    79544
# 5    74840
# Name: sub_grade, dtype: int64

# %%
plt.figure(figsize=(12,10))
sns.histplot(data4.sub_grade)
# Out:
# <AxesSubplot:xlabel='sub_grade', ylabel='Count'>

# %% [markdown]
# ### 4. address

# %%
data4.address.value_counts()
# Out:
# 70466    56985
# 30723    56546
# 22690    56527
# 48052    55917
# 00813    45824
# 29597    45471
# 05113    45402
# 11650    11226
# 93700    11151
# 86630    10981
# Name: address, dtype: int64

# %%
plt.figure(figsize=(12,10))
sns.histplot(data4.address)
# Out:
# <AxesSubplot:xlabel='address', ylabel='Count'>

# %% [markdown]
# ## New Correlations

# %% [markdown]
# ### 1. earliest_cr_line_month and earliest_cr_line_year

# %%
data4.corr().loan_status.abs().sort_values()[:-1]
# Out:
# earliest_cr_line_month    0.003861
# pub_rec_bankruptcies      0.009383
# revol_bal                 0.010892
# total_acc                 0.017893
# pub_rec                   0.019933
# open_acc                  0.028012
# earliest_cr_line_year     0.038928
# installment               0.041082
# annual_inc                0.053432
# loan_amnt                 0.059836
# dti                       0.062413
# mort_acc                  0.073111
# revol_util                0.082373
# int_rate                  0.247758
# Name: loan_status, dtype: float64

# %%
correl2=pd.DataFrame(data4.corr().loan_status.sort_values()[:-1]).reset_index()

# %%
correl2
# Out:
#                      index  loan_status
# 0                 int_rate    -0.247758
# 1               revol_util    -0.082373
# 2                      dti    -0.062413
# 3                loan_amnt    -0.059836
# 4              installment    -0.041082
# 5    earliest_cr_line_year    -0.038928
# 6                 open_acc    -0.028012
# 7                  pub_rec    -0.019933
# 8     pub_rec_bankruptcies    -0.009383
# 9   earliest_cr_line_month     0.003861
# 10               revol_bal     0.010892
# 11               total_acc     0.017893
# 12              annual_inc     0.053432
# 13                mort_acc     0.073111

# %%
plt.figure(figsize=(12,10))
sns.barplot(y='index',x='loan_status',data=correl2,palette='viridis')
# Out:
# <AxesSubplot:xlabel='loan_status', ylabel='index'>

# %% [markdown]
# **Among new features, year-feature is negatively correlated with loan_status. Month-feature have negligible correlations**

# %% [markdown]
# ### 2. sub_grade

# %% [markdown]
# #### Bivariate plot showing label ratios

# %%
plt.figure(figsize=(20,10))
sns.histplot(data=data4,x='sub_grade',hue='loan_status',palette='hot_r',multiple='fill')
# Out:
# <AxesSubplot:xlabel='sub_grade', ylabel='Count'>

# %% [markdown]
# #### Target variable distribution in different sub_grade

# %%
sub_grade_df=data4.groupby('sub_grade').loan_status.mean()
sub_grade_df
# Out:
# sub_grade
# 1    0.813992
# 2    0.804611
# 3    0.803675
# 4    0.800319
# 5    0.796165
# Name: loan_status, dtype: float64

# %% [markdown]
# **Label distribution is similar**

# %% [markdown]
# ### 3. address

# %% [markdown]
# #### Bivariate plot showing label ratios

# %%
plt.figure(figsize=(20,10))
sns.histplot(data=data4,x='address',hue='loan_status',palette='hot_r',multiple='fill')
# Out:
# <AxesSubplot:xlabel='address', ylabel='Count'>

# %% [markdown]
# #### Target variable distribution in different address(zipcodes)

# %%
address_df=data4.groupby('address').loan_status.mean()
address_df
# Out:
# address
# 00813    1.000000
# 05113    1.000000
# 11650    0.000000
# 22690    0.806216
# 29597    1.000000
# 30723    0.805097
# 48052    0.799846
# 70466    0.804370
# 86630    0.000000
# 93700    0.000000
# Name: loan_status, dtype: float64

# %% [markdown]
# **Label distribution is very different**

# %% [markdown]
# #### value_counts

# %%
data4.address.value_counts()
# Out:
# 70466    56985
# 30723    56546
# 22690    56527
# 48052    55917
# 00813    45824
# 29597    45471
# 05113    45402
# 11650    11226
# 93700    11151
# 86630    10981
# Name: address, dtype: int64

# %%
data4.address.value_counts(normalize=True)*100
# Out:
# 70466    14.389061
# 30723    14.278211
# 22690    14.273414
# 48052    14.119385
# 00813    11.570841
# 29597    11.481706
# 05113    11.464283
# 11650     2.834634
# 93700     2.815696
# 86630     2.772770
# Name: address, dtype: float64

# %% [markdown]
# **address(zipcodes) has very good correlation with label as seen from very different label distribution : Important feature**

# %% [markdown]
# # Feature Selection

# %% [markdown]
# ## Features with null values

# %%
data4.isnull().sum()
# Out:
# loan_amnt                     0
# term                          0
# int_rate                      0
# installment                   0
# grade                         0
# sub_grade                     0
# emp_title                 22927
# emp_length                18301
# home_ownership                0
# annual_inc                    0
# verification_status           0
# issue_d                       0
# loan_status                   0
# purpose                       0
# title                      1755
# dti                           0
# open_acc                      0
# pub_rec                       0
# revol_bal                     0
# revol_util                  276
# total_acc                     0
# initial_list_status           0
# application_type              0
# mort_acc                  37795
# pub_rec_bankruptcies        535
# address                       0
# earliest_cr_line_month        0
# earliest_cr_line_year         0
# dtype: int64

# %% [markdown]
# ## Categorical features: emp_title and title have too many unique values

# %%
data4.emp_title.describe()
# Out:
# count      373103
# unique     173105
# top       Teacher
# freq         4389
# Name: emp_title, dtype: object

# %%
data4.title.describe()
# Out:
# count                 394275
# unique                 48817
# top       Debt consolidation
# freq                  152472
# Name: title, dtype: object

# %% [markdown]
# ## Data Leakage

# %% [markdown]
# ### issue_d

# %%
info[info.LoanStatNew=='issue_d'].Description
# Out:
# 11    The month which the loan was funded
# Name: Description, dtype: object

# %%
data4.issue_d.describe()
# Out:
# count       396030
# unique         115
# top       Oct-2014
# freq         14846
# Name: issue_d, dtype: object

# %% [markdown]
# **Need to be removed to prevent data leakage(theoretically)**

# %% [markdown]
# ## Numerical features with very less correlation to label

# %%
data4.corr().loan_status.abs().sort_values().head()
# Out:
# earliest_cr_line_month    0.003861
# pub_rec_bankruptcies      0.009383
# revol_bal                 0.010892
# total_acc                 0.017893
# pub_rec                   0.019933
# Name: loan_status, dtype: float64

# %% [markdown]
# **earliest_cr_line_month: 0.003861 and pub_rec_bankruptcies: 0.009383 have very less correlation**

# %% [markdown]
# ### 1. earliest_cr_line_month

# %%
data4.earliest_cr_line_month.describe()
# Out:
# count    396030.000000
# mean          6.756231
# std           3.435011
# min           1.000000
# 25%           4.000000
# 50%           7.000000
# 75%          10.000000
# max          12.000000
# Name: earliest_cr_line_month, dtype: float64

# %% [markdown]
# ### 2. pub_rec_bankruptcies

# %%
data4.pub_rec_bankruptcies.describe()
# Out:
# count    395495.000000
# mean          0.121648
# std           0.356174
# min           0.000000
# 25%           0.000000
# 50%           0.000000
# 75%           0.000000
# max           8.000000
# Name: pub_rec_bankruptcies, dtype: float64

# %% [markdown]
# ## Categorical features with very less correlation to label

# %%
cat_cols=data4.select_dtypes('object').drop(['emp_title','issue_d','title'],axis=1).columns
cat_cols
# Out:
# Index(['term', 'grade', 'sub_grade', 'emp_length', 'home_ownership',
#        'verification_status', 'purpose', 'initial_list_status',
#        'application_type', 'address'],
#       dtype='object')

# %%
cat_corr=pd.DataFrame(data=cat_cols,columns=['Feature'],)
cat_corr
# Out:
#                Feature
# 0                 term
# 1                grade
# 2            sub_grade
# 3           emp_length
# 4       home_ownership
# 5  verification_status
# 6              purpose
# 7  initial_list_status
# 8     application_type
# 9              address

# %% [markdown]
# ### Label distribution in each category

# %%
cat_corr['Label_dist']=cat_corr['Feature'].apply(lambda feat:[data4.groupby(feat).loan_status.mean()])
cat_corr
# Out:
#                Feature  \
# 0                 term
# 1                grade
# 2            sub_grade
# 3           emp_length
# 4       home_ownership
# 5  verification_status
# 6              purpose
# 7  initial_list_status
# 8     application_type
# 9              address
#
#                                                                                                                                                                                                                                                                                  Label_dist
# 0                                                                                                                                                                                                                                                [[0.8422542673134551, 0.6805849508109545]]
# 1                                                                                                                                            [[0.9371212239238476, 0.8742695099036356, 0.7881910045571626, 0.7113217051822933, 0.6263655995934959, 0.5721202854230377, 0.5216110019646365]]
# 2                                                                                                                                                                                    [[0.8139916375790914, 0.8046112843206276, 0.8036753637732063, 0.8003191134089476, 0.7961651523249599]]
# 3                                                             [[0.8008654663472684, 0.8158139018255964, 0.8067379350768973, 0.8047686720353703, 0.8076152304609219, 0.807812794866956, 0.8108056235305408, 0.8052259954848936, 0.8002399833055092, 0.7995298419746637, 0.7931284475965327]]
# 4                                                                                                                                                                                 [[1.0, 0.830439429689233, 0.7741935483870968, 0.8571428571428571, 0.7931966301065013, 0.773377558044934]]
# 5                                                                                                                                                                                                                            [[0.8536400121520282, 0.7852570689195875, 0.7767889770211303]]
# 6  [[0.8652331275282095, 0.8328816295064985, 0.7925861488143211, 0.8365758754863813, 0.8299209321681231, 0.8028169014084507, 0.8352673492605234, 0.7828884652049571, 0.7652417659425368, 0.787821571866887, 0.7659574468085106, 0.705490264865813, 0.8107667210440457, 0.8791390728476821]]
# 7                                                                                                                                                                                                                                                [[0.8069400922433275, 0.7992453976855486]]
# 8                                                                                                                                                                                                                            [[0.6433566433566433, 0.8039127894181661, 0.8729411764705882]]
# 9                                                                                                                                                                           [[1.0, 1.0, 0.0, 0.8062164983105419, 1.0, 0.8050967354012663, 0.7998462006187742, 0.804369570939721, 0.0, 0.0]]

# %% [markdown]
# ### Standard deviation of label distributions in each category

# %%
cat_corr['Std']=cat_corr['Label_dist'].apply(lambda dist:np.array(dist).std())
cat_corr[['Feature','Std']].sort_values('Std')
# Out:
#                Feature       Std
# 7  initial_list_status  0.003847
# 3           emp_length  0.005867
# 2            sub_grade  0.005915
# 5  verification_status  0.034406
# 6              purpose  0.043411
# 4       home_ownership  0.078446
# 0                 term  0.080835
# 8     application_type  0.096178
# 1                grade  0.144246
# 9              address  0.414928

# %% [markdown]
# **initial_list_status, emp_length and sub_grade have least standard deviation in label distribution**

# %% [markdown]
# #### 1. initial_list_status

# %%
initial_list_status_df.values.std()
# Out:
# 0.003847347278889468

# %% [markdown]
# #### 2. emp_length

# %%
emp_lengths_df.values.std()
# Out:
# 0.005866562369941041

# %% [markdown]
# #### 3. sub_grade

# %%
sub_grade_df.values.std()
# Out:
# 0.005915055149285235

# %% [markdown]
# ## Dropping features

# %%
data5=data4.copy()

# %%
data5.drop(['emp_title','title','issue_d','earliest_cr_line_month','pub_rec_bankruptcies','initial_list_status','emp_length','sub_grade'],axis=1,inplace=True)

# %%
data5.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 396030 entries, 0 to 396029
# Data columns (total 20 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   loan_amnt              396030 non-null  float64
#  1   term                   396030 non-null  object
#  2   int_rate               396030 non-null  float64
#  3   installment            396030 non-null  float64
#  4   grade                  396030 non-null  object
#  5   home_ownership         396030 non-null  object
#  6   annual_inc             396030 non-null  float64
#  7   verification_status    396030 non-null  object
#  8   loan_status            396030 non-null  uint8
#  9   purpose                396030 non-null  object
#  10  dti                    396030 non-null  float64
#  11  open_acc               396030 non-null  float64
#  12  pub_rec                396030 non-null  float64
#  13  revol_bal              396030 non-null  float64
#  14  revol_util             395754 non-null  float64
#  15  total_acc              396030 non-null  float64
#  16  application_type       396030 non-null  object
#  17  mort_acc               358235 non-null  float64
#  18  address                396030 non-null  object
#  19  earliest_cr_line_year  396030 non-null  int64
# dtypes: float64(11), int64(1), object(7), uint8(1)
# memory usage: 57.8+ MB

# %% [markdown]
# # Data Cleaning

# %% [markdown]
# ## Checking for nulls

# %%
data5.isnull()
# Out:
#         loan_amnt   term  int_rate  installment  grade  home_ownership  \
# 0           False  False     False        False  False           False
# 1           False  False     False        False  False           False
# 2           False  False     False        False  False           False
# 3           False  False     False        False  False           False
# 4           False  False     False        False  False           False
# ...           ...    ...       ...          ...    ...             ...
# 396025      False  False     False        False  False           False
# 396026      False  False     False        False  False           False
# 396027      False  False     False        False  False           False
# 396028      False  False     False        False  False           False
# 396029      False  False     False        False  False           False
#
#         annual_inc  verification_status  loan_status  purpose    dti  \
# 0            False                False        False    False  False
# 1            False                False        False    False  False
# 2            False                False        False    False  False
# 3            False                False        False    False  False
# 4            False                False        False    False  False
# ...            ...                  ...          ...      ...    ...
# 396025       False                False        False    False  False
# 396026       False                False        False    False  False
# 396027       False                False        False    False  False
# 396028       False                False        False    False  False
# 396029       False                False        False    False  False
#
#         open_acc  pub_rec  revol_bal  revol_util  total_acc  application_type  \
# 0          False    False      False       False      False             False
# 1          False    False      False       False      False             False
# 2          False    False      False       False      False             False
# 3          False    False      False       False      False             False
# 4          False    False      False       False      False             False
# ...          ...      ...        ...         ...        ...               ...
# 396025     False    False      False       False      False             False
# 396026     False    False      False       False      False             False
# 396027     False    False      False       False      False             False
# 396028     False    False      False       False      False             False
# 396029     False    False      False       False      False             False
#
#         mort_acc  address  earliest_cr_line_year
# 0          False    False                  False
# 1          False    False                  False
# 2          False    False                  False
# 3          False    False                  False
# 4          False    False                  False
# ...          ...      ...                    ...
# 396025     False    False                  False
# 396026     False    False                  False
# 396027     False    False                  False
# 396028     False    False                  False
# 396029      True    False                  False
#
# [396030 rows x 20 columns]

# %%
plt.figure(figsize=(20,15))
sns.heatmap(data5.isnull(),yticklabels=False, cbar=False)
# Out:
# <AxesSubplot:>

# %%
data5.isnull().sum()
# Out:
# loan_amnt                    0
# term                         0
# int_rate                     0
# installment                  0
# grade                        0
# home_ownership               0
# annual_inc                   0
# verification_status          0
# loan_status                  0
# purpose                      0
# dti                          0
# open_acc                     0
# pub_rec                      0
# revol_bal                    0
# revol_util                 276
# total_acc                    0
# application_type             0
# mort_acc                 37795
# address                      0
# earliest_cr_line_year        0
# dtype: int64

# %%
nulls_now=data5.isna().sum()
nulls_now[nulls_now.values!=0]
# Out:
# revol_util      276
# mort_acc      37795
# dtype: int64

# %% [markdown]
# ### Percentage missing

# %%
nulls_now[nulls_now.values!=0]/len(data5)*100
# Out:
# revol_util    0.069692
# mort_acc      9.543469
# dtype: float64

# %% [markdown]
# ## Features with nulls

# %% [markdown]
# ### 1. mort_acc : 37795 nulls

# %%
info[info.LoanStatNew=='mort_acc'].Description
# Out:
# 26    Number of mortgage accounts.
# Name: Description, dtype: object

# %%
data5.mort_acc.describe()
# Out:
# count    358235.000000
# mean          1.813991
# std           2.147930
# min           0.000000
# 25%           0.000000
# 50%           1.000000
# 75%           3.000000
# max          34.000000
# Name: mort_acc, dtype: float64

# %%
data5.corr().mort_acc.sort_values()[:-1]
# Out:
# earliest_cr_line_year   -0.291298
# int_rate                -0.082583
# dti                     -0.025439
# revol_util               0.007514
# pub_rec                  0.011552
# loan_status              0.073111
# open_acc                 0.109205
# installment              0.193694
# revol_bal                0.194925
# loan_amnt                0.222315
# annual_inc               0.236320
# total_acc                0.381072
# Name: mort_acc, dtype: float64

# %% [markdown]
# **total_acc has highest correlation with mort_acc**

# %% [markdown]
# #### Filling mort_acc based on total_acc

# %%
data6=data5.copy()

# %%
nulls_now=data6.isna().sum()
nulls_now[nulls_now.values!=0]
# Out:
# revol_util      276
# mort_acc      37795
# dtype: int64

# %%
data6.groupby('total_acc').mort_acc.value_counts()
# Out:
# total_acc  mort_acc
# 2.0        0.0          16
# 3.0        0.0         165
#            1.0           7
#            2.0           1
# 4.0        0.0         815
#                       ...
# 124.0      1.0           1
# 129.0      1.0           1
# 135.0      3.0           1
# 150.0      2.0           1
# 151.0      0.0           1
# Name: mort_acc, Length: 1243, dtype: int64

# %%
fill_df=data6.groupby('total_acc').mort_acc.mean()
fill_df
# Out:
# total_acc
# 2.0      0.000000
# 3.0      0.052023
# 4.0      0.066743
# 5.0      0.103289
# 6.0      0.151293
#            ...
# 124.0    1.000000
# 129.0    1.000000
# 135.0    3.000000
# 150.0    2.000000
# 151.0    0.000000
# Name: mort_acc, Length: 118, dtype: float64

# %% [markdown]
# **Function to fill missing values**

# %%
def fill_mort_acc(tot,mort):
    if np.isnan(mort)==True:
        mort=fill_df[tot]
    return mort

# %%
data6.mort_acc=data6.apply(lambda x:fill_mort_acc(x.total_acc,x.mort_acc),axis=1)

# %%
nulls_now=data6.isna().sum()
nulls_now[nulls_now.values!=0]
# Out:
# revol_util    276
# dtype: int64

# %% [markdown]
# ### 2. revol_util : 276 nulls

# %%
info[info.LoanStatNew=='revol_util'].Description
# Out:
# 22    Revolving line utilization rate, or the amount of credit the borrower is using relative to all available revolving credit.
# Name: Description, dtype: object

# %%
data5.revol_util.describe()
# Out:
# count    395754.000000
# mean         53.791749
# std          24.452193
# min           0.000000
# 25%          35.800000
# 50%          54.800000
# 75%          72.900000
# max         892.300000
# Name: revol_util, dtype: float64

# %% [markdown]
# #### Percentage missing

# %%
nulls_now[nulls_now.values!=0]/len(data5)*100
# Out:
# revol_util    0.069692
# dtype: float64

# %% [markdown]
# **Less than 0.1 percentage of values missing**

# %% [markdown]
# #### Dropping rows with missing values

# %%
data7=data6.copy()

# %%
data7.dropna(inplace=True)

# %%
nulls_now=data7.isna().sum()
nulls_now[nulls_now.values!=0]
# Out:
# Series([], dtype: int64)

# %% [markdown]
# **No more null values**

# %% [markdown]
# ## home_ownership has columns with very few entries

# %%
info[info.LoanStatNew=='home_ownership'].Description
# Out:
# 8    The home ownership status provided by the borrower during registration or obtained from the credit report. Our values are: RENT, OWN, MORTGAGE, OTHER
# Name: Description, dtype: object

# %%
data7.home_ownership.describe()
# Out:
# count       395754
# unique           6
# top       MORTGAGE
# freq        198219
# Name: home_ownership, dtype: object

# %%
data7.home_ownership.value_counts()
# Out:
# MORTGAGE    198219
# RENT        159677
# OWN          37714
# OTHER          110
# NONE            31
# ANY              3
# Name: home_ownership, dtype: int64

# %% [markdown]
# ### Replacing 'NONE' and 'ANY' values with 'OTHER'

# %%
data8=data7.copy()

# %%
data8.home_ownership.replace(['NONE','ANY'],'OTHER',inplace=True)

# %%
data8.home_ownership.value_counts()
# Out:
# MORTGAGE    198219
# RENT        159677
# OWN          37714
# OTHER          144
# Name: home_ownership, dtype: int64

# %% [markdown]
# # Data Encoding

# %% [markdown]
# ## Remaining Categorical Features

# %%
data8.select_dtypes('object').info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 395754 entries, 0 to 396029
# Data columns (total 7 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   term                 395754 non-null  object
#  1   grade                395754 non-null  object
#  2   home_ownership       395754 non-null  object
#  3   verification_status  395754 non-null  object
#  4   purpose              395754 non-null  object
#  5   application_type     395754 non-null  object
#  6   address              395754 non-null  object
# dtypes: object(7)
# memory usage: 24.2+ MB

# %% [markdown]
# **term has numerical data : can be converted to numerical feature**

# %% [markdown]
# ### Converting term to int

# %%
data8.term.value_counts()
# Out:
#  36 months    301782
#  60 months     93972
# Name: term, dtype: int64

# %%
data9=data8.copy()

# %%
data9.term.iloc[0][:3]
# Out:
# ' 36'

# %%
data9.term=data9.term.apply(lambda x:int(x[1:3]))

# %%
data9.term.value_counts()
# Out:
# 36    301782
# 60     93972
# Name: term, dtype: int64

# %% [markdown]
# ### Remaining Categorical Features

# %%
data9.select_dtypes('object').info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 395754 entries, 0 to 396029
# Data columns (total 6 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   grade                395754 non-null  object
#  1   home_ownership       395754 non-null  object
#  2   verification_status  395754 non-null  object
#  3   purpose              395754 non-null  object
#  4   application_type     395754 non-null  object
#  5   address              395754 non-null  object
# dtypes: object(6)
# memory usage: 21.1+ MB

# %% [markdown]
# ## Dummy Encoding

# %%
data9.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 395754 entries, 0 to 396029
# Data columns (total 20 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   loan_amnt              395754 non-null  float64
#  1   term                   395754 non-null  int64
#  2   int_rate               395754 non-null  float64
#  3   installment            395754 non-null  float64
#  4   grade                  395754 non-null  object
#  5   home_ownership         395754 non-null  object
#  6   annual_inc             395754 non-null  float64
#  7   verification_status    395754 non-null  object
#  8   loan_status            395754 non-null  uint8
#  9   purpose                395754 non-null  object
#  10  dti                    395754 non-null  float64
#  11  open_acc               395754 non-null  float64
#  12  pub_rec                395754 non-null  float64
#  13  revol_bal              395754 non-null  float64
#  14  revol_util             395754 non-null  float64
#  15  total_acc              395754 non-null  float64
#  16  application_type       395754 non-null  object
#  17  mort_acc               395754 non-null  float64
#  18  address                395754 non-null  object
#  19  earliest_cr_line_year  395754 non-null  int64
# dtypes: float64(11), int64(2), object(6), uint8(1)
# memory usage: 60.8+ MB

# %%
data10=data9.copy()

# %%
data10.select_dtypes('object')
# Out:
#        grade home_ownership verification_status             purpose  \
# 0          B           RENT        Not Verified            vacation
# 1          B       MORTGAGE        Not Verified  debt_consolidation
# 2          B           RENT     Source Verified         credit_card
# 3          A           RENT        Not Verified         credit_card
# 4          C       MORTGAGE            Verified         credit_card
# ...      ...            ...                 ...                 ...
# 396025     B           RENT     Source Verified  debt_consolidation
# 396026     C       MORTGAGE     Source Verified  debt_consolidation
# 396027     B           RENT            Verified  debt_consolidation
# 396028     C       MORTGAGE            Verified  debt_consolidation
# 396029     C           RENT            Verified  debt_consolidation
#
#        application_type address
# 0            INDIVIDUAL   22690
# 1            INDIVIDUAL   05113
# 2            INDIVIDUAL   05113
# 3            INDIVIDUAL   00813
# 4            INDIVIDUAL   11650
# ...                 ...     ...
# 396025       INDIVIDUAL   30723
# 396026       INDIVIDUAL   05113
# 396027       INDIVIDUAL   70466
# 396028       INDIVIDUAL   29597
# 396029       INDIVIDUAL   48052
#
# [395754 rows x 6 columns]

# %%
dummies=pd.get_dummies(data10.select_dtypes('object'),drop_first=True)
dummies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 395754 entries, 0 to 396029
# Data columns (total 35 columns):
#  #   Column                               Non-Null Count   Dtype
# ---  ------                               --------------   -----
#  0   grade_B                              395754 non-null  uint8
#  1   grade_C                              395754 non-null  uint8
#  2   grade_D                              395754 non-null  uint8
#  3   grade_E                              395754 non-null  uint8
#  4   grade_F                              395754 non-null  uint8
#  5   grade_G                              395754 non-null  uint8
#  6   home_ownership_OTHER                 395754 non-null  uint8
#  7   home_ownership_OWN                   395754 non-null  uint8
#  8   home_ownership_RENT                  395754 non-null  uint8
#  9   verification_status_Source Verified  395754 non-null  uint8
#  10  verification_status_Verified         395754 non-null  uint8
#  11  purpose_credit_card                  395754 non-null  uint8
#  12  purpose_debt_consolidation           395754 non-null  uint8
#  13  purpose_educational                  395754 non-null  uint8
#  14  purpose_home_improvement             395754 non-null  uint8
#  15  purpose_house                        395754 non-null  uint8
#  16  purpose_major_purchase               395754 non-null  uint8
#  17  purpose_medical                      395754 non-null  uint8
#  18  purpose_moving                       395754 non-null  uint8
#  19  purpose_other                        395754 non-null  uint8
#  20  purpose_renewable_energy             395754 non-null  uint8
#  21  purpose_small_business               395754 non-null  uint8
#  22  purpose_vacation                     395754 non-null  uint8
#  23  purpose_wedding                      395754 non-null  uint8
#  24  application_type_INDIVIDUAL          395754 non-null  uint8
#  25  application_type_JOINT               395754 non-null  uint8
#  26  address_05113                        395754 non-null  uint8
#  27  address_11650                        395754 non-null  uint8
#  28  address_22690                        395754 non-null  uint8
#  29  address_29597                        395754 non-null  uint8
#  30  address_30723                        395754 non-null  uint8
#  31  address_48052                        395754 non-null  uint8
#  32  address_70466                        395754 non-null  uint8
#  33  address_86630                        395754 non-null  uint8
#  34  address_93700                        395754 non-null  uint8
# dtypes: uint8(35)
# memory usage: 16.2 MB

# %% [markdown]
# ## Removing original features

# %%
data10.drop(data10.select_dtypes('object').columns.to_list(),axis=1,inplace=True)
data10.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 395754 entries, 0 to 396029
# Data columns (total 14 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   loan_amnt              395754 non-null  float64
#  1   term                   395754 non-null  int64
#  2   int_rate               395754 non-null  float64
#  3   installment            395754 non-null  float64
#  4   annual_inc             395754 non-null  float64
#  5   loan_status            395754 non-null  uint8
#  6   dti                    395754 non-null  float64
#  7   open_acc               395754 non-null  float64
#  8   pub_rec                395754 non-null  float64
#  9   revol_bal              395754 non-null  float64
#  10  revol_util             395754 non-null  float64
#  11  total_acc              395754 non-null  float64
#  12  mort_acc               395754 non-null  float64
#  13  earliest_cr_line_year  395754 non-null  int64
# dtypes: float64(11), int64(2), uint8(1)
# memory usage: 42.6 MB

# %% [markdown]
# ## Adding dummies

# %%
data11=data10.copy()

# %%
data11=pd.concat([data11,dummies],axis=1)
data11.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 395754 entries, 0 to 396029
# Data columns (total 49 columns):
#  #   Column                               Non-Null Count   Dtype
# ---  ------                               --------------   -----
#  0   loan_amnt                            395754 non-null  float64
#  1   term                                 395754 non-null  int64
#  2   int_rate                             395754 non-null  float64
#  3   installment                          395754 non-null  float64
#  4   annual_inc                           395754 non-null  float64
#  5   loan_status                          395754 non-null  uint8
#  6   dti                                  395754 non-null  float64
#  7   open_acc                             395754 non-null  float64
#  8   pub_rec                              395754 non-null  float64
#  9   revol_bal                            395754 non-null  float64
#  10  revol_util                           395754 non-null  float64
#  11  total_acc                            395754 non-null  float64
#  12  mort_acc                             395754 non-null  float64
#  13  earliest_cr_line_year                395754 non-null  int64
#  14  grade_B                              395754 non-null  uint8
#  15  grade_C                              395754 non-null  uint8
#  16  grade_D                              395754 non-null  uint8
#  17  grade_E                              395754 non-null  uint8
#  18  grade_F                              395754 non-null  uint8
#  19  grade_G                              395754 non-null  uint8
#  20  home_ownership_OTHER                 395754 non-null  uint8
#  21  home_ownership_OWN                   395754 non-null  uint8
#  22  home_ownership_RENT                  395754 non-null  uint8
#  23  verification_status_Source Verified  395754 non-null  uint8
#  24  verification_status_Verified         395754 non-null  uint8
#  25  purpose_credit_card                  395754 non-null  uint8
#  26  purpose_debt_consolidation           395754 non-null  uint8
#  27  purpose_educational                  395754 non-null  uint8
#  28  purpose_home_improvement             395754 non-null  uint8
#  29  purpose_house                        395754 non-null  uint8
#  30  purpose_major_purchase               395754 non-null  uint8
#  31  purpose_medical                      395754 non-null  uint8
#  32  purpose_moving                       395754 non-null  uint8
#  33  purpose_other                        395754 non-null  uint8
#  34  purpose_renewable_energy             395754 non-null  uint8
#  35  purpose_small_business               395754 non-null  uint8
#  36  purpose_vacation                     395754 non-null  uint8
#  37  purpose_wedding                      395754 non-null  uint8
#  38  application_type_INDIVIDUAL          395754 non-null  uint8
#  39  application_type_JOINT               395754 non-null  uint8
#  40  address_05113                        395754 non-null  uint8
#  41  address_11650                        395754 non-null  uint8
#  42  address_22690                        395754 non-null  uint8
#  43  address_29597                        395754 non-null  uint8
#  44  address_30723                        395754 non-null  uint8
#  45  address_48052                        395754 non-null  uint8
#  46  address_70466                        395754 non-null  uint8
#  47  address_86630                        395754 non-null  uint8
#  48  address_93700                        395754 non-null  uint8
# dtypes: float64(11), int64(2), uint8(36)
# memory usage: 55.9 MB

# %% [markdown]
# # Data Splitting

# %%
X=data11.drop('loan_status',axis=1).values
y=data11.loan_status.values

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)

# %% [markdown]
# # Data Normalization

# %%
scaler=MinMaxScaler()

# %%
X_train=scaler.fit_transform(X_train)
X_test=scaler.transform(X_test)

# %% [markdown]
# # Deep learning Model

# %%
X_train.shape
# Out:
# (265155, 48)

# %%
model=Sequential()
model.add(Dense(48,activation='relu'))
model.add(Dropout(0.2))

model.add(Dense(24,activation='relu'))
model.add(Dropout(0.2))

model.add(Dense(1,activation='sigmoid'))

model.compile(loss='binary_crossentropy',optimizer='adam')

# %% [markdown]
# #### Number of batches

# %%
len(X_train)/256
# Out:
# 1035.76171875

# %% [markdown]
# **1036 batches of size 256**

# %% [markdown]
# #### EarlyStopping callback

# %%
early_stop=EarlyStopping(monitor='val_loss',mode='min',verbose=1,patience=25)

# %%
model.fit(x=X_train,y=y_train,batch_size=256,epochs=500,validation_data=(X_test,y_test),callbacks=[early_stop])
# Out:
# Epoch 1/500
# 1036/1036 [==============================] - 9s 6ms/step - loss: 0.3085 - val_loss: 0.2634
# Epoch 2/500
# 1036/1036 [==============================] - 5s 5ms/step - loss: 0.2653 - val_loss: 0.2617
# Epoch 3/500
# 1036/1036 [==============================] - 5s 5ms/step - loss: 0.2622 - val_loss: 0.2605
# Epoch 4/500
# 1036/1036 [==============================] - 5s 4ms/step - loss: 0.2610 - val_loss: 0.2598
# Epoch 5/500
# 1036/1036 [==============================] - 5s 4ms/step - loss: 0.2601 - val_loss: 0.2591
# Epoch 6/500
# 1036/1036 [==============================] - 5s 4ms/step - loss: 0.2594 - val_loss: 0.2592
# Epoch 7/500
# 1036/1036 [==============================] - 5s 4ms/step - loss: 0.2590 - val_loss: 0.2588
# Epoch 8/500
# 1036/1036 [==============================] - 5s 4ms/step - loss: 0.2588 - val_loss: 0.2588
# Epoch 9/500
# 1036/1036 [==============================] - 5s 4ms/step - loss: 0.2584 - val_loss: 0.2588
# Epoch 10/500
# 1036/1036 [==============================] - 5s 5ms/step - loss: 0.2581 - val_loss: 0.2598
# Epoch 11/500
# 1036/1036 [==============================] - 5s 4ms/step - loss: 0.2579 - val_loss: 0.2586
# Epoch 12/500
# 1036/1036 [==============================] - 5s 5ms/step - loss: 0.2579 - val_loss: 0.2592
# Epoch 13/500
# 1036/1036 [==============================] - 5s 4ms/step - loss: 0.2577 - val_loss: 0.2588
# Epoch 14/500
# 1036/1036 [==============================] - 5s 4ms/step - loss: 0.2578 - val_loss: 0.2584
# Epoch 15/500
# 1036/1036 [==============================] - 5s 4ms/step - loss: 0.2574 - val_loss: 0.2589
# Epoch 16/500
# 1036/1036 [==============================] - 5s 5ms/step - loss: 0.2576 - val_loss: 0.2592
# Epoch 17/500
# 1036/1036 [==============================] - 5s 4ms/step - loss: 0.2574 - val_loss: 0.2590
# Epoch 18/500
# 1036/1036 [==============================] - 5s 4ms/step - loss: 0.2572 - val_loss: 0.2592
# Epoch 19/500
# 1036/1036 [==============================] - 5s 4ms/step - loss: 0.2571 - val_loss: 0.2588
# Epoch 20/500
# 1036/1036 [==============================] - 5s 4ms/step - loss: 0.2571 - val_loss: 0.2587
# Epoch 21/500
# 1036/1036 [==============================] - 6s 5ms/step - loss: 0.2569 - val_loss: 0.2589
# Epoch 22/500
# 1036/1036 [==============================] - 5s 5ms/step - loss: 0.2569 - val_loss: 0.2586
# Epoch 23/500
# 1036/1036 [==============================] - 5s 4ms/step - loss: 0.2568 - val_loss: 0.2586
# Epoch 24/500
# 1036/1036 [==============================] - 6s 6ms/step - loss: 0.2569 - val_loss: 0.2587
# Epoch 25/500
# 1036/1036 [==============================] - 7s 7ms/step - loss: 0.2568 - val_loss: 0.2594
# Epoch 26/500
# 1036/1036 [==============================] - 5s 4ms/step - loss: 0.2565 - val_loss: 0.2594
# Epoch 27/500
# 1036/1036 [==============================] - 5s 5ms/step - loss: 0.2564 - val_loss: 0.2587
# Epoch 28/500
# 1036/1036 [==============================] - 5s 5ms/step - loss: 0.2564 - val_loss: 0.2588
# Epoch 29/500
# 1036/1036 [==============================] - 5s 5ms/step - loss: 0.2561 - val_loss: 0.2587
# Epoch 30/500
# 1036/1036 [==============================] - 5s 4ms/step - loss: 0.2566 - val_loss: 0.2587
# Epoch 31/500
# 1036/1036 [==============================] - 5s 5ms/step - loss: 0.2563 - val_loss: 0.2595
# Epoch 32/500
# 1036/1036 [==============================] - 5s 4ms/step - loss: 0.2563 - val_loss: 0.2587
# Epoch 33/500
# 1036/1036 [==============================] - 5s 4ms/step - loss: 0.2563 - val_loss: 0.2588
# Epoch 34/500
# 1036/1036 [==============================] - 4s 4ms/step - loss: 0.2561 - val_loss: 0.2590
# Epoch 35/500
# 1036/1036 [==============================] - 5s 5ms/step - loss: 0.2563 - val_loss: 0.2587
# Epoch 36/500
# 1036/1036 [==============================] - 5s 4ms/step - loss: 0.2562 - val_loss: 0.2586
# Epoch 37/500
# 1036/1036 [==============================] - 5s 4ms/step - loss: 0.2559 - val_loss: 0.2586
# Epoch 38/500
# 1036/1036 [==============================] - 5s 5ms/step - loss: 0.2558 - val_loss: 0.2589
# Epoch 39/500
# 1036/1036 [==============================] - 5s 5ms/step - loss: 0.2560 - val_loss: 0.2586
# Epoch 39: early stopping

# %% [markdown]
#  # Evaluating model performance

# %%
losses=pd.DataFrame(model.history.history)
losses
# Out:
#         loss  val_loss
# 0   0.308463  0.263360
# 1   0.265325  0.261690
# 2   0.262175  0.260546
# 3   0.261049  0.259823
# 4   0.260149  0.259147
# 5   0.259439  0.259159
# 6   0.258974  0.258811
# 7   0.258811  0.258802
# 8   0.258371  0.258828
# 9   0.258137  0.259759
# 10  0.257931  0.258606
# 11  0.257943  0.259222
# 12  0.257725  0.258790
# 13  0.257768  0.258421
# 14  0.257449  0.258905
# 15  0.257608  0.259190
# 16  0.257424  0.258973
# 17  0.257226  0.259245
# 18  0.257101  0.258768
# 19  0.257078  0.258724
# 20  0.256930  0.258871
# 21  0.256892  0.258580
# 22  0.256827  0.258616
# 23  0.256883  0.258747
# 24  0.256779  0.259400
# 25  0.256489  0.259374
# 26  0.256425  0.258710
# 27  0.256392  0.258811
# 28  0.256103  0.258657
# 29  0.256605  0.258697
# 30  0.256277  0.259549
# 31  0.256298  0.258666
# 32  0.256306  0.258813
# 33  0.256109  0.259029
# 34  0.256339  0.258737
# 35  0.256194  0.258644
# 36  0.255925  0.258640
# 37  0.255819  0.258919
# 38  0.256050  0.258582

# %%
losses.plot(figsize=(12,10))
# Out:
# <AxesSubplot:>

# %%
predictions=(model.predict(X_test)>0.5)*1
predictions
# Out:
# 4082/4082 [==============================] - 7s 2ms/step
# array([[1],
#        [1],
#        [1],
#        ...,
#        [1],
#        [1],
#        [1]])

# %%
print(classification_report(y_test,predictions))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.96      0.45      0.62     25569
#            1       0.88      0.99      0.94    105030
#
#     accuracy                           0.89    130599
#    macro avg       0.92      0.72      0.78    130599
# weighted avg       0.90      0.89      0.87    130599

# %%
print(confusion_matrix(y_test,predictions))
# Out:
# [[ 11621  13948]
#  [   545 104485]]

# %% [markdown]
# # Testing model for a random data

# %%
random.seed(101)
random_ind=random.randint(0,len(data11))

new_customer=data11.drop('loan_status',axis=1).iloc[random_ind]
new_customer
# Out:
# loan_amnt                                6000.00
# term                                       36.00
# int_rate                                   10.49
# installment                               194.99
# annual_inc                             103916.00
# dti                                        14.82
# open_acc                                    7.00
# pub_rec                                     1.00
# revol_bal                               10875.00
# revol_util                                 86.30
# total_acc                                  14.00
# mort_acc                                    1.00
# earliest_cr_line_year                    2001.00
# grade_B                                     1.00
# grade_C                                     0.00
# grade_D                                     0.00
# grade_E                                     0.00
# grade_F                                     0.00
# grade_G                                     0.00
# home_ownership_OTHER                        0.00
# home_ownership_OWN                          0.00
# home_ownership_RENT                         1.00
# verification_status_Source Verified         1.00
# verification_status_Verified                0.00
# purpose_credit_card                         0.00
# purpose_debt_consolidation                  1.00
# purpose_educational                         0.00
# purpose_home_improvement                    0.00
# purpose_house                               0.00
# purpose_major_purchase                      0.00
# purpose_medical                             0.00
# purpose_moving                              0.00
# purpose_other                               0.00
# purpose_renewable_energy                    0.00
# purpose_small_business                      0.00
# purpose_vacation                            0.00
# purpose_wedding                             0.00
# application_type_INDIVIDUAL                 1.00
# application_type_JOINT                      0.00
# address_05113                               1.00
# address_11650                               0.00
# address_22690                               0.00
# address_29597                               0.00
# address_30723                               0.00
# address_48052                               0.00
# address_70466                               0.00
# address_86630                               0.00
# address_93700                               0.00
# Name: 304917, dtype: float64

# %% [markdown]
# #### Scaling

# %%
new_customer=scaler.transform(new_customer.values.reshape(1,48))

# %% [markdown]
# #### Prediction

# %%
model.predict(new_customer)>0.5
# Out:
# 1/1 [==============================] - 0s 61ms/step
# array([[ True]])

# %% [markdown]
# **Predicted that random customer pays back the loan**

# %% [markdown]
# #### Checking

# %%
random_ind
# Out:
# 304691

# %%
data11['loan_status'].iloc[random_ind]
# Out:
# 1

# %% [markdown]
# **Customer did pay back the loan**
